# %% [markdown]
# # Portfolio starts from 2023-01-01 since that's when portfolio became fully healthcare

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import yfinance as yf
import os


# Set pandas display options to show all columns
pd.set_option('display.max_columns', None)  # Show all columns
pd.set_option('display.width', None)        # Adjust width to avoid truncation

# Set plot style for better aesthetics
sns.set(style="whitegrid")

start_date = "2023-01-01"

def load_portfolio_data(file_path,start_date):
    """Load and preprocess portfolio data."""
    df = pd.read_excel(file_path)
    df.columns = df.columns.str.strip()
    df.rename(columns={"Trade Dt": "Date", "Group": "Ticker"}, inplace=True)
    df['Date'] = pd.to_datetime(df['Date']).ffill()
    df["Returns_Percent"] = df["P&L (%)"]
    
    # Filter to start from 2023-01-01
    df = df[df['Date'] >= start_date]
    
    return df

def load_ff5_data(file_path,start_date):
    """Load and preprocess F-F 5 Factors data."""
    df = pd.read_csv(file_path)
    df['Date'] = pd.to_datetime(df['Date'], format='%Y%m%d')
    
    # Filter to start from 2023-01-01
    df = df[df['Date'] >= start_date]
    
    return df

def fetch_biotech_index_data(tickers,start_date):
    """Fetch historical adjusted close data for specified tickers."""
    data = yf.download(tickers,start=start_date)['Adj Close']
    daily_returns = data.pct_change().dropna()
    daily_returns.columns = ['XBI_Daily_Returns', 'NBI_Daily_Returns', 'IWM_Daily_Returns']
    daily_returns.reset_index(inplace=True)
    daily_returns['Date'] = pd.to_datetime(daily_returns['Date'], utc=True).dt.tz_localize(None)
    
    # Filter to start from 2023-01-01
    daily_returns = daily_returns[daily_returns['Date'] >= start_date]
    
    return daily_returns

def merge_data(portfolio, ff5, biotech_returns,start_date):
    # Ensure all Date columns are naive
    portfolio['Date'] = portfolio['Date'].dt.tz_localize(None)
    ff5['Date'] = ff5['Date'].dt.tz_localize(None)
    biotech_returns['Date'] = pd.to_datetime(biotech_returns['Date']).dt.tz_localize(None)

    # Subset F-F 5 Factors and Biotech Index to match the portfolio date range

    ff5_subset = ff5[ff5['Date'] >= start_date]
    biotech_subset = biotech_returns[biotech_returns['Date'] >= start_date]

    # Merge the dataframes
    merged = pd.merge(portfolio, ff5_subset, on='Date', how='left')
    final = pd.merge(merged, biotech_subset, on='Date', how='left')

    return final

# Main execution
portfolio_file_path = r"C:\Users\MukeshwaranBaskaran\Downloads\Project_KISKI\Data\ADAR1_Daily_Ticker_Data.xlsx"
ff5_file_path = r"C:\Users\MukeshwaranBaskaran\Downloads\Project_KISKI\Data\F-F_Research_Data_5_Factors_2x3_daily.CSV"
index_tickers = ['XBI', '^NBI', 'IWM']

# Load data
df_daily_portfolio = load_portfolio_data(portfolio_file_path,start_date)
df_ff5_daily = load_ff5_data(ff5_file_path,start_date)
biotech_index_daily_returns = fetch_biotech_index_data(index_tickers,start_date)

# Execute the merging function
final_df = merge_data(df_daily_portfolio, df_ff5_daily, biotech_index_daily_returns,start_date)

# Display the final dataframe
df = final_df.dropna(subset=['Ticker'])

# Replace ' JP' at the end with '.T'
df['Ticker'] = df['Ticker'].apply(lambda x: x[:-3] + '.T' if x.endswith(' JP') else x)

# Replace '2746505Z DC' with 'ASND'
df['Ticker'] = df['Ticker'].replace('2746505Z DC', 'ASND')
df.head()
# Out:
# [*********************100%***********************]  3 of 3 completed
# C:\Users\MukeshwaranBaskaran\AppData\Local\Temp\ipykernel_6592\2578415963.py:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Ticker'] = df['Ticker'].apply(lambda x: x[:-3] + '.T' if x.endswith(' JP') else x)
# C:\Users\MukeshwaranBaskaran\AppData\Local\Temp\ipykernel_6592\2578415963.py:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Ticker'] = df['Ticker'].replace('2746505Z DC', 'ASND')
#         Date    Ticker       AUM BOD       AUM EOD       P&L   P&L (%)  \
# 1 2023-01-31    4502.T  7.268115e+07  7.561933e+07   4156.44  0.000057
# 2 2023-01-31    4523.T  7.268115e+07  7.561933e+07  30633.20  0.000421
# 3 2023-01-31  1893407D  7.268115e+07  7.561933e+07       NaN       NaN
# 4 2023-01-31      ASND  7.268115e+07  7.561933e+07   -495.87 -0.000007
# 5 2023-01-31      AADI  7.268115e+07  7.561933e+07   -974.67 -0.000013
#
#              Net   Net (%)          Gross  Gross(%)  Market Value  \
# 1  723114.700000  0.009563  723114.700000  0.009563     723114.70
# 2   92382.190000  0.001222   92382.190000  0.001222      92382.19
# 3  120000.000000  0.001587  120000.000000  0.001587     120000.00
# 4            NaN       NaN            NaN       NaN           NaN
# 5   50196.076239  0.000664   50196.076239  0.000664      32649.00
#
#    Market Value (%)  Returns_Percent  Mkt-RF   SMB   HML   RMW   CMA     RF  \
# 1          0.009563         0.000057    1.58  0.94 -0.07 -0.06 -0.51  0.017
# 2          0.001222         0.000421    1.58  0.94 -0.07 -0.06 -0.51  0.017
# 3          0.001587              NaN    1.58  0.94 -0.07 -0.06 -0.51  0.017
# 4               NaN        -0.000007    1.58  0.94 -0.07 -0.06 -0.51  0.017
# 5          0.000432        -0.000013    1.58  0.94 -0.07 -0.06 -0.51  0.017
#
#    XBI_Daily_Returns  NBI_Daily_Returns  IWM_Daily_Returns
# 1           0.024286           0.020666           0.011836
# 2           0.024286           0.020666           0.011836
# 3           0.024286           0.020666           0.011836
# 4           0.024286           0.020666           0.011836
# 5           0.024286           0.020666           0.011836

# %%
# Create a subfolder for storing data
data_folder = 'yfinance_data'
os.makedirs(data_folder, exist_ok=True)

# Initialize lists to hold tickers and results
successful_tickers = []
failed_tickers = []

# Define the time period
start_date = '2018-01-01'
end_date = pd.Timestamp.now().strftime('%Y-%m-%d')

# Loop through each ticker in the DataFrame
for ticker in df['Ticker'].unique():
    file_path = os.path.join(data_folder, f"{ticker}_data.csv")
    
    try:
        # Check if the file already exists
        if os.path.exists(file_path):
            # Load existing data
            existing_data = pd.read_csv(file_path, parse_dates=['Date'], index_col='Date')
            latest_date = existing_data.index[-1]

            # If the latest data is from today, skip fetching
            if latest_date.date() == pd.Timestamp.now().date():
                successful_tickers.append(ticker)
                continue
            
            # Adjust the start date for fetching new data
            start_date = latest_date.strftime('%Y-%m-%d')
        
        # Fetch historical data from Yahoo Finance
        data = yf.download(ticker, start=start_date, end=end_date)
        
        if not data.empty:
            # Append new data if any
            if os.path.exists(file_path):
                data = pd.concat([existing_data, data])
                data = data[~data.index.duplicated(keep='last')]  # Remove duplicates if any
            
            # Save the updated data to a CSV file
            data.to_csv(file_path)
            successful_tickers.append(ticker)
        else:
            failed_tickers.append(ticker)
    
    except Exception as e:
        print(f"Failed to fetch data for {ticker}: {e}")
        failed_tickers.append(ticker)

# Save the list of tickers with no data to a separate CSV
failed_df = pd.DataFrame(failed_tickers, columns=['Failed Tickers'])
failed_df.to_csv('failed_tickers.csv', index=False)

# Save the successful tickers to a CSV
successful_df = pd.DataFrame(successful_tickers, columns=['Successful Tickers'])
successful_df.to_csv('successful_tickers.csv', index=False)

print("Data fetching complete.")
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['1893407D']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ACACW']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2018-01-01 -> 2024-10-11)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ACAXR']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ACAXW']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2018-01-01 -> 2024-10-11)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ADOCR']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AEAC']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AEACW']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AIMAW']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2018-01-01 -> 2024-10-11)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ALBO']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [**********************50%                       ]  2 of 4 completedFailed to get ticker '09/28/27' reason: Expecting value: line 1 column 1 (char 0)
# [*********************100%***********************]  4 of 4 completed
#
# 3 Failed downloads:
# ['$4.215', '09/28/27', 'WARRANTS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# Failed to fetch data for ANEB Warrants 09/28/27 $4.215: Cannot save file into a non-existent directory: 'yfinance_data\ANEB Warrants 09\28'
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  2 of 2 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ASTLW']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2018-01-01 -> 2024-10-11)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AVEO']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  2 of 2 completed
#
# 1 Failed download:
# ['BAYN']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['BLU']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['BMY-R']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  2 of 2 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['CASHPOS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['CBAY']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['CBRGF']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2018-01-01 -> 2024-10-11)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['CCVI']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['CERE']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['CINC']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['CTIC']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['CVIIW']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2018-01-01 -> 2024-10-11)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['DCP']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['DCPH']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['DCRDW']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['DECAW']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2018-01-01 -> 2024-10-11)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['DHAIW']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2018-01-01 -> 2024-10-11)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['DLCA']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['DLCAW']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ECDAW']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2018-01-01 -> 2024-10-11)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['EFHT']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['EFHTR']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['EMCGR']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2018-01-01 -> 2024-10-11)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['EMCGW']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2018-01-01 -> 2024-10-11)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['EPZM']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ESALY']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['FATP']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['FEE_USD']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['FINM']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['FINMW']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['FLFVR']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2018-01-01 -> 2024-10-11)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['FLFVW']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2018-01-01 -> 2024-10-11)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['FSTX']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['FTIIW']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2018-01-01 -> 2024-10-11)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['FZT']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['GIIX']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['GLSTR']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2018-01-01 -> 2024-10-11)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['GLSTW']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2018-01-01 -> 2024-10-11)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['GRCYF']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['GRPH']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  2 of 2 completed
#
# 1 Failed download:
# ['LN']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['HUGS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['HZNP']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2018-01-01 -> 2024-10-11)')
# Failed to get ticker 'HZON/WS' reason: Expecting value: line 1 column 1 (char 0)
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['HZON/WS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ICPT']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ICUCW']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2018-01-01 -> 2024-10-11)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['IMGN']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['IMGO']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['IRNTQ']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ISEE']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  2 of 2 completed
#
# 1 Failed download:
# ['JOY']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2018-01-01 -> 2024-10-11)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['KDNY']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['KIII']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2018-01-01 -> 2024-10-11)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['KIIIW']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2018-01-01 -> 2024-10-11)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['KRTX']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['LIONW']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['LOKM']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['MACK']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['MDH']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['MDHAW']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['MEOAW']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['MIT']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['MITGW']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['MOBV']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['MOBVW']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['MSPR']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2018-01-01 -> 2024-10-11)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['MYOV']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['NGM']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['NIHD']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['NIRWQ']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  2 of 2 completed
#
# 1 Failed download:
# ['NOVOB']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['NUBI']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['NUBIW']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2018-01-01 -> 2024-10-11)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['NVCN']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['NVTAQ']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2018-01-01 -> 2024-10-11) (Yahoo error = "No data found, symbol may be delisted")')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['OCAXW']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2018-01-01 -> 2024-10-11)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ONFOW']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2018-01-01 -> 2024-10-11)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['OPNT']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['OTIC']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2018-01-01 -> 2024-10-11)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['OYST']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['PACX']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  2 of 2 completed
#
# 2 Failed downloads:
# ['XW']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2018-01-01 -> 2024-10-11)')
# ['PLRXEUR']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['PMGM']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['PMGMW']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['PNT']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['POSH']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  2 of 2 completed
#
# 1 Failed download:
# ['LN']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['PRVB']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['PSTH']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['PTWOW']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2018-01-01 -> 2024-10-11)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['RETA']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['REVRQ']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  2 of 2 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['RXDX']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SBBP']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SCRM']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SDACW']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SGEN']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SIOX']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2018-01-01 -> 2024-10-11)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SIRE']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  2 of 2 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SSPCF']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['STSA']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SVFA']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SVFB']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SWAV']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['TCDAQ']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['TCRR']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [                       0%                       ]Could not get exchangeTimezoneName for ticker '' reason: 'chart'
# [*********************100%***********************]  2 of 2 completed
#
# 1 Failed download:
# ['']: %ticker%Y%ticker%F%ticker%T%ticker%z%ticker%M%ticker%i%ticker%s%ticker%s%ticker%i%ticker%n%ticker%g%ticker%E%ticker%r%ticker%r%ticker%o%ticker%r%ticker%(%ticker%'%ticker%$%ticker%:%ticker% %ticker%p%ticker%o%ticker%s%ticker%s%ticker%i%ticker%b%ticker%l%ticker%y%ticker% %ticker%d%ticker%e%ticker%l%ticker%i%ticker%s%ticker%t%ticker%e%ticker%d%ticker%;%ticker% %ticker%n%ticker%o%ticker% %ticker%t%ticker%i%ticker%m%ticker%e%ticker%z%ticker%o%ticker%n%ticker%e%ticker% %ticker%f%ticker%o%ticker%u%ticker%n%ticker%d%ticker%'%ticker%)%ticker%
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  2 of 2 completed
#
# 1 Failed download:
# ['VOW3']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['WPCA']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['WPCAF']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['WPCB']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['WPCBF']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ZGNX']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ZVSAW']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2018-01-01 -> 2024-10-11)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['CANO']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['CETUU']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['FUSN']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  2 of 2 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['HHC']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['HHRSW']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2018-01-01 -> 2024-10-11)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['JNCE']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['LNDC']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  2 of 2 completed
#
# 2 Failed downloads:
# ['1480990D', 'ID']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['2152294D']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ALPN']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  2 of 2 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['DCTHWS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['NSTGQ']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SIVB']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2018-01-01 -> 2024-10-11)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SMXWW']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2018-01-01 -> 2024-10-11)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['THRX']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  2 of 2 completed
#
# 1 Failed download:
# ['LN']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  2 of 2 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  2 of 2 completed
#
# 1 Failed download:
# ['BIOAB']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['LIFE']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['PRDS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [                       0%                       ]Could not get exchangeTimezoneName for ticker '' reason: 'chart'
# [*********************100%***********************]  2 of 2 completed
#
# 1 Failed download:
# ['']: %ticker%Y%ticker%F%ticker%T%ticker%z%ticker%M%ticker%i%ticker%s%ticker%s%ticker%i%ticker%n%ticker%g%ticker%E%ticker%r%ticker%r%ticker%o%ticker%r%ticker%(%ticker%'%ticker%$%ticker%:%ticker% %ticker%p%ticker%o%ticker%s%ticker%s%ticker%i%ticker%b%ticker%l%ticker%y%ticker% %ticker%d%ticker%e%ticker%l%ticker%i%ticker%s%ticker%t%ticker%e%ticker%d%ticker%;%ticker% %ticker%n%ticker%o%ticker% %ticker%t%ticker%i%ticker%m%ticker%e%ticker%z%ticker%o%ticker%n%ticker%e%ticker% %ticker%f%ticker%o%ticker%u%ticker%n%ticker%d%ticker%'%ticker%)%ticker%
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AMAM']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ...
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ARYD']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  2 of 2 completed
#
# 1 Failed download:
# ['NBLY']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  2 of 2 completed
#
# 1 Failed download:
# ['FP']: Y%ticker%ricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2018-01-01 -> 2024-10-11)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ASLN']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  2 of 2 completed
#
# 1 Failed download:
# ['GY']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2018-01-01 -> 2024-10-11)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  2 of 2 completed
#
# 2 Failed downloads:
# ['GY']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2018-01-01 -> 2024-10-11)')
# ['1SXP']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  2 of 2 completed
#
# 1 Failed download:
# ['2411443D']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  2 of 2 completed
#
# 1 Failed download:
# ['AVRXX']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['LABP']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  2 of 2 completed
#
# 1 Failed download:
# ['MDNA']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2018-01-01 -> 2024-10-11)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  2 of 2 completed
#
# 1 Failed download:
# ['UR']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2018-01-01 -> 2024-10-11)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['FIGXX']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2018-01-01 -> 2024-10-11)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  2 of 2 completed
#
# 1 Failed download:
# ['22Z']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['2268338D']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  2 of 2 completed
#
# 1 Failed download:
# ['CURNCY']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ZURAW']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2018-01-01 -> 2024-10-11)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  2 of 2 completed
#
# 2 Failed downloads:
# ['GY', 'FIE']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2018-01-01 -> 2024-10-11)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  2 of 2 completed
#
# 1 Failed download:
# ['LONN']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  2 of 2 completed
#
# 1 Failed download:
# ['ALM']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2018-01-01 -> 2024-10-11)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [                       0%                       ]Could not get exchangeTimezoneName for ticker '' reason: list index out of range
# [*********************100%***********************]  2 of 2 completed
#
# 1 Failed download:
# ['']: %ticker%Y%ticker%F%ticker%T%ticker%z%ticker%M%ticker%i%ticker%s%ticker%s%ticker%i%ticker%n%ticker%g%ticker%E%ticker%r%ticker%r%ticker%o%ticker%r%ticker%(%ticker%'%ticker%$%ticker%:%ticker% %ticker%p%ticker%o%ticker%s%ticker%s%ticker%i%ticker%b%ticker%l%ticker%y%ticker% %ticker%d%ticker%e%ticker%l%ticker%i%ticker%s%ticker%t%ticker%e%ticker%d%ticker%;%ticker% %ticker%n%ticker%o%ticker% %ticker%t%ticker%i%ticker%m%ticker%e%ticker%z%ticker%o%ticker%n%ticker%e%ticker% %ticker%f%ticker%o%ticker%u%ticker%n%ticker%d%ticker%'%ticker%)%ticker%
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  2 of 2 completed
#
# 1 Failed download:
# ['SDZ']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2018-01-01 -> 2024-10-11)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['0968190D']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Failed to get ticker 'AAM/U' reason: Expecting value: line 1 column 1 (char 0)
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AAM/U']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['FST']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['MKDWW']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2018-01-01 -> 2024-10-11)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  2 of 2 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  2 of 2 completed
#
# 1 Failed download:
# ['RTYU4']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AITRR']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2018-01-01 -> 2024-10-11)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['BKHAR']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2018-01-01 -> 2024-10-11)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['IROHR']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2018-01-01 -> 2024-10-11)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['IROHW']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2018-01-01 -> 2024-10-11)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['JVSAR']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2018-01-01 -> 2024-10-11)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['NNAGR']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2018-01-01 -> 2024-10-11)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['NNAGW']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2018-01-01 -> 2024-10-11)')
# [*********************100%***********************]  2 of 2 completed
#
# 1 Failed download:
# ['GUBRA']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data fetching complete.

# %%
# Create a dictionary to hold the adjusted close data for all tickers
adjusted_close_data = {}

# Loop through each unique ticker in the DataFrame
for ticker in df['Ticker'].unique():
    file_path = os.path.join(data_folder, f"{ticker}_data.csv")
    
    # Debug output for file paths
    print(f"Processing file: {file_path}")
    
    if os.path.exists(file_path):
        # Read CSV and clean column names
        temp_data = pd.read_csv(file_path)
        temp_data.columns = temp_data.columns.str.strip()  # Strip whitespace from column names
        
        # Debug output for column names
        print(f"Columns found in {file_path}: {temp_data.columns.tolist()}")
        
        if 'Date' in temp_data.columns:
            # Read adjusted close data while parsing dates
            existing_data = pd.read_csv(file_path, parse_dates=['Date'], index_col='Date')
            existing_data.reset_index(inplace=True)
            
            # Add the ticker column
            existing_data['Ticker'] = ticker
            
            # Store the adjusted close data
            adjusted_close_data[ticker] = existing_data[['Date', 'Ticker', 'Adj Close']].rename(columns={'Adj Close': 'Adj_Close'})
        else:
            print(f"Column 'Date' not found in {file_path}")
    else:
        print(f"File not found: {file_path}")

# Combine all adjusted close data into a single DataFrame
if adjusted_close_data:  # Check if there's any data to concatenate
    adjusted_close_df = pd.concat(adjusted_close_data.values(), ignore_index=True)
else:
    print("No adjusted close data found for any tickers.")
    adjusted_close_df = pd.DataFrame()  # Create an empty DataFrame if no data

# Final DataFrame output
print("Final adjusted close DataFrame:")
print(adjusted_close_df.head())  # Display first few rows for verification
# Out:
# Processing file: yfinance_data\4502.T_data.csv
# Columns found in yfinance_data\4502.T_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\4523.T_data.csv
# Columns found in yfinance_data\4523.T_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\1893407D_data.csv
# File not found: yfinance_data\1893407D_data.csv
# Processing file: yfinance_data\ASND_data.csv
# Columns found in yfinance_data\ASND_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\AADI_data.csv
# Columns found in yfinance_data\AADI_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\AAGR_data.csv
# Columns found in yfinance_data\AAGR_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\ABBV_data.csv
# Columns found in yfinance_data\ABBV_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\ABCL_data.csv
# Columns found in yfinance_data\ABCL_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\ACAC_data.csv
# Columns found in yfinance_data\ACAC_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\ACACU_data.csv
# Columns found in yfinance_data\ACACU_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\ACACW_data.csv
# File not found: yfinance_data\ACACW_data.csv
# Processing file: yfinance_data\ACAD_data.csv
# Columns found in yfinance_data\ACAD_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\ACAXR_data.csv
# File not found: yfinance_data\ACAXR_data.csv
# Processing file: yfinance_data\ACAXW_data.csv
# File not found: yfinance_data\ACAXW_data.csv
# Processing file: yfinance_data\ACET_data.csv
# Columns found in yfinance_data\ACET_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\ACHV_data.csv
# Columns found in yfinance_data\ACHV_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\ACRS_data.csv
# Columns found in yfinance_data\ACRS_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\ADAP_data.csv
# Columns found in yfinance_data\ADAP_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\ADMA_data.csv
# Columns found in yfinance_data\ADMA_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\ADOCR_data.csv
# File not found: yfinance_data\ADOCR_data.csv
# Processing file: yfinance_data\ADPT_data.csv
# Columns found in yfinance_data\ADPT_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\AEAC_data.csv
# File not found: yfinance_data\AEAC_data.csv
# Processing file: yfinance_data\AEACW_data.csv
# File not found: yfinance_data\AEACW_data.csv
# Processing file: yfinance_data\AGEN_data.csv
# Columns found in yfinance_data\AGEN_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\AGIO_data.csv
# Columns found in yfinance_data\AGIO_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\AGL_data.csv
# Columns found in yfinance_data\AGL_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\AIEV_data.csv
# Columns found in yfinance_data\AIEV_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\AIMAW_data.csv
# File not found: yfinance_data\AIMAW_data.csv
# Processing file: yfinance_data\AIMBU_data.csv
# Columns found in yfinance_data\AIMBU_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\AKBA_data.csv
# Columns found in yfinance_data\AKBA_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\AKRO_data.csv
# Columns found in yfinance_data\AKRO_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\ALBO_data.csv
# File not found: yfinance_data\ALBO_data.csv
# Processing file: yfinance_data\ALKS_data.csv
# Columns found in yfinance_data\ALKS_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\ALLO_data.csv
# Columns found in yfinance_data\ALLO_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\ALNY_data.csv
# Columns found in yfinance_data\ALNY_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\ALT_data.csv
# Columns found in yfinance_data\ALT_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\AMBD_data.csv
# Columns found in yfinance_data\AMBD_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\AMLX_data.csv
# Columns found in yfinance_data\AMLX_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\ANAB_data.csv
# Columns found in yfinance_data\ANAB_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\ANEB_data.csv
# Columns found in yfinance_data\ANEB_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\ANEB Warrants 09/28/27 $4.215_data.csv
# File not found: yfinance_data\ANEB Warrants 09/28/27 $4.215_data.csv
# Processing file: yfinance_data\ANIP_data.csv
# Columns found in yfinance_data\ANIP_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\APLS_data.csv
# Columns found in yfinance_data\APLS_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\ARCT_data.csv
# Columns found in yfinance_data\ARCT_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\ARDS_data.csv
# Columns found in yfinance_data\ARDS_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\ARDX_data.csv
# Columns found in yfinance_data\ARDX_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\ARKK_data.csv
# Columns found in yfinance_data\ARKK_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\ARRY_data.csv
# Columns found in yfinance_data\ARRY_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\ARWR_data.csv
# Columns found in yfinance_data\ARWR_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\ASML NA_data.csv
# Columns found in yfinance_data\ASML NA_data.csv: ['Price', 'Adj Close', 'Adj Close.1', 'Close', 'Close.1', 'High', 'High.1', 'Low', 'Low.1', 'Open', 'Open.1', 'Volume', 'Volume.1']
# Column 'Date' not found in yfinance_data\ASML NA_data.csv
# Processing file: yfinance_data\ASTLW_data.csv
# File not found: yfinance_data\ASTLW_data.csv
# Processing file: yfinance_data\ATEC_data.csv
# Columns found in yfinance_data\ATEC_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\ATNM_data.csv
# Columns found in yfinance_data\ATNM_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\ATXS_data.csv
# Columns found in yfinance_data\ATXS_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\AUTL_data.csv
# Columns found in yfinance_data\AUTL_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\AVDL_data.csv
# Columns found in yfinance_data\AVDL_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\AVEO_data.csv
# File not found: yfinance_data\AVEO_data.csv
# Processing file: yfinance_data\AVIR_data.csv
# Columns found in yfinance_data\AVIR_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\AVXL_data.csv
# Columns found in yfinance_data\AVXL_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\BAYN GR_data.csv
# Columns found in yfinance_data\BAYN GR_data.csv: ['Price', 'Adj Close', 'Adj Close.1', 'Close', 'Close.1', 'High', 'High.1', 'Low', 'Low.1', 'Open', 'Open.1', 'Volume', 'Volume.1']
# Column 'Date' not found in yfinance_data\BAYN GR_data.csv
# Processing file: yfinance_data\BBIO_data.csv
# Columns found in yfinance_data\BBIO_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\BCAB_data.csv
# Columns found in yfinance_data\BCAB_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\BCRX_data.csv
# Columns found in yfinance_data\BCRX_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\BHVN_data.csv
# Columns found in yfinance_data\BHVN_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\BIIB_data.csv
# Columns found in yfinance_data\BIIB_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\BLU_data.csv
# File not found: yfinance_data\BLU_data.csv
# Processing file: yfinance_data\BLUE_data.csv
# Columns found in yfinance_data\BLUE_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\BMRN_data.csv
# Columns found in yfinance_data\BMRN_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\BMY_data.csv
# Columns found in yfinance_data\BMY_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\BMY-R_data.csv
# File not found: yfinance_data\BMY-R_data.csv
# Processing file: yfinance_data\BNAI_data.csv
# Columns found in yfinance_data\BNAI_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\BTE CN_data.csv
# Columns found in yfinance_data\BTE CN_data.csv: ['Price', 'Adj Close', 'Adj Close.1', 'Close', 'Close.1', 'High', 'High.1', 'Low', 'Low.1', 'Open', 'Open.1', 'Volume', 'Volume.1']
# Column 'Date' not found in yfinance_data\BTE CN_data.csv
# Processing file: yfinance_data\BUR_data.csv
# Columns found in yfinance_data\BUR_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\BYND_data.csv
# Columns found in yfinance_data\BYND_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\CashPos_data.csv
# File not found: yfinance_data\CashPos_data.csv
# Processing file: yfinance_data\CBAY_data.csv
# File not found: yfinance_data\CBAY_data.csv
# Processing file: yfinance_data\CBRG_data.csv
# Columns found in yfinance_data\CBRG_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\CBRGF_data.csv
# File not found: yfinance_data\CBRGF_data.csv
# Processing file: yfinance_data\CCVI_data.csv
# File not found: yfinance_data\CCVI_data.csv
# Processing file: yfinance_data\CDMO_data.csv
# Columns found in yfinance_data\CDMO_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\CERE_data.csv
# File not found: yfinance_data\CERE_data.csv
# Processing file: yfinance_data\CHRS_data.csv
# Columns found in yfinance_data\CHRS_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\CINC_data.csv
# File not found: yfinance_data\CINC_data.csv
# Processing file: yfinance_data\CLDX_data.csv
# Columns found in yfinance_data\CLDX_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\CLNN_data.csv
# Columns found in yfinance_data\CLNN_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\CLWY_data.csv
# Columns found in yfinance_data\CLWY_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\CMPO_data.csv
# Columns found in yfinance_data\CMPO_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\COGT_data.csv
# Columns found in yfinance_data\COGT_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\CORT_data.csv
# Columns found in yfinance_data\CORT_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\CRBU_data.csv
# Columns found in yfinance_data\CRBU_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\CRIS_data.csv
# Columns found in yfinance_data\CRIS_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\CTIC_data.csv
# File not found: yfinance_data\CTIC_data.csv
# Processing file: yfinance_data\CTMX_data.csv
# Columns found in yfinance_data\CTMX_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\CVII_data.csv
# Columns found in yfinance_data\CVII_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\CVIIW_data.csv
# File not found: yfinance_data\CVIIW_data.csv
# Processing file: yfinance_data\CYTK_data.csv
# Columns found in yfinance_data\CYTK_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\DAWN_data.csv
# Columns found in yfinance_data\DAWN_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\DCP_data.csv
# File not found: yfinance_data\DCP_data.csv
# Processing file: yfinance_data\DCPH_data.csv
# File not found: yfinance_data\DCPH_data.csv
# Processing file: yfinance_data\DCRDW_data.csv
# File not found: yfinance_data\DCRDW_data.csv
# Processing file: yfinance_data\DECA_data.csv
# Columns found in yfinance_data\DECA_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\DECAW_data.csv
# File not found: yfinance_data\DECAW_data.csv
# Processing file: yfinance_data\DHAIW_data.csv
# File not found: yfinance_data\DHAIW_data.csv
# Processing file: yfinance_data\DLCA_data.csv
# File not found: yfinance_data\DLCA_data.csv
# Processing file: yfinance_data\DLCAW_data.csv
# File not found: yfinance_data\DLCAW_data.csv
# Processing file: yfinance_data\DMSL_data.csv
# Columns found in yfinance_data\DMSL_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\DNA_data.csv
# Columns found in yfinance_data\DNA_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\DNLI_data.csv
# Columns found in yfinance_data\DNLI_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\DNTH_data.csv
# Columns found in yfinance_data\DNTH_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\ECDAW_data.csv
# File not found: yfinance_data\ECDAW_data.csv
# Processing file: yfinance_data\EDR_data.csv
# Columns found in yfinance_data\EDR_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\EFHT_data.csv
# File not found: yfinance_data\EFHT_data.csv
# Processing file: yfinance_data\EFHTR_data.csv
# File not found: yfinance_data\EFHTR_data.csv
# Processing file: yfinance_data\EMCG_data.csv
# Columns found in yfinance_data\EMCG_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\EMCGR_data.csv
# File not found: yfinance_data\EMCGR_data.csv
# Processing file: yfinance_data\EMCGW_data.csv
# File not found: yfinance_data\EMCGW_data.csv
# Processing file: yfinance_data\EPZM_data.csv
# File not found: yfinance_data\EPZM_data.csv
# Processing file: yfinance_data\ERAS_data.csv
# Columns found in yfinance_data\ERAS_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\ESALY_data.csv
# File not found: yfinance_data\ESALY_data.csv
# Processing file: yfinance_data\ESPR_data.csv
# Columns found in yfinance_data\ESPR_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\ETNB_data.csv
# Columns found in yfinance_data\ETNB_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\EVH_data.csv
# Columns found in yfinance_data\EVH_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\EXAS_data.csv
# Columns found in yfinance_data\EXAS_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\EXEL_data.csv
# Columns found in yfinance_data\EXEL_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\FATE_data.csv
# Columns found in yfinance_data\FATE_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\FATP_data.csv
# File not found: yfinance_data\FATP_data.csv
# Processing file: yfinance_data\FEE_USD_data.csv
# File not found: yfinance_data\FEE_USD_data.csv
# Processing file: yfinance_data\FGEN_data.csv
# Columns found in yfinance_data\FGEN_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\FINM_data.csv
# File not found: yfinance_data\FINM_data.csv
# Processing file: yfinance_data\FINMW_data.csv
# File not found: yfinance_data\FINMW_data.csv
# Processing file: yfinance_data\FLFVR_data.csv
# File not found: yfinance_data\FLFVR_data.csv
# Processing file: yfinance_data\FLFVW_data.csv
# File not found: yfinance_data\FLFVW_data.csv
# Processing file: yfinance_data\FLR_data.csv
# Columns found in yfinance_data\FLR_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\FOLD_data.csv
# Columns found in yfinance_data\FOLD_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\FSTX_data.csv
# File not found: yfinance_data\FSTX_data.csv
# Processing file: yfinance_data\FTII_data.csv
# Columns found in yfinance_data\FTII_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\FTIIW_data.csv
# File not found: yfinance_data\FTIIW_data.csv
# Processing file: yfinance_data\FUN_data.csv
# Columns found in yfinance_data\FUN_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\FZT_data.csv
# File not found: yfinance_data\FZT_data.csv
# Processing file: yfinance_data\GERN_data.csv
# Columns found in yfinance_data\GERN_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\GIIX_data.csv
# File not found: yfinance_data\GIIX_data.csv
# Processing file: yfinance_data\GLBL_data.csv
# Columns found in yfinance_data\GLBL_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\GLRE_data.csv
# Columns found in yfinance_data\GLRE_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\GLST_data.csv
# Columns found in yfinance_data\GLST_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\GLSTR_data.csv
# File not found: yfinance_data\GLSTR_data.csv
# Processing file: yfinance_data\GLSTW_data.csv
# File not found: yfinance_data\GLSTW_data.csv
# Processing file: yfinance_data\GOSS_data.csv
# Columns found in yfinance_data\GOSS_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\GRCYF_data.csv
# File not found: yfinance_data\GRCYF_data.csv
# Processing file: yfinance_data\GROW_data.csv
# Columns found in yfinance_data\GROW_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\GRPH_data.csv
# File not found: yfinance_data\GRPH_data.csv
# Processing file: yfinance_data\GS_data.csv
# Columns found in yfinance_data\GS_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\GSK LN_data.csv
# Columns found in yfinance_data\GSK LN_data.csv: ['Price', 'Adj Close', 'Adj Close.1', 'Close', 'Close.1', 'High', 'High.1', 'Low', 'Low.1', 'Open', 'Open.1', 'Volume', 'Volume.1']
# Column 'Date' not found in yfinance_data\GSK LN_data.csv
# Processing file: yfinance_data\GTLB_data.csv
# Columns found in yfinance_data\GTLB_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\GYRE_data.csv
# Columns found in yfinance_data\GYRE_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\HGTY_data.csv
# Columns found in yfinance_data\HGTY_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\HUGS_data.csv
# File not found: yfinance_data\HUGS_data.csv
# Processing file: yfinance_data\HWH_data.csv
# Columns found in yfinance_data\HWH_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\HZNP_data.csv
# File not found: yfinance_data\HZNP_data.csv
# Processing file: yfinance_data\HZON/WS_data.csv
# File not found: yfinance_data\HZON/WS_data.csv
# Processing file: yfinance_data\ICPT_data.csv
# File not found: yfinance_data\ICPT_data.csv
# Processing file: yfinance_data\ICUCW_data.csv
# File not found: yfinance_data\ICUCW_data.csv
# Processing file: yfinance_data\IEZ_data.csv
# Columns found in yfinance_data\IEZ_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\IFIN_data.csv
# Columns found in yfinance_data\IFIN_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\IIPR_data.csv
# Columns found in yfinance_data\IIPR_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\IMCR_data.csv
# Columns found in yfinance_data\IMCR_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\IMGN_data.csv
# File not found: yfinance_data\IMGN_data.csv
# Processing file: yfinance_data\IMGO_data.csv
# File not found: yfinance_data\IMGO_data.csv
# Processing file: yfinance_data\IMVT_data.csv
# Columns found in yfinance_data\IMVT_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\INCY_data.csv
# Columns found in yfinance_data\INCY_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\INSM_data.csv
# Columns found in yfinance_data\INSM_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\IOVA_data.csv
# Columns found in yfinance_data\IOVA_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\IPA_data.csv
# Columns found in yfinance_data\IPA_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\IRNTQ_data.csv
# File not found: yfinance_data\IRNTQ_data.csv
# Processing file: yfinance_data\ISEE_data.csv
# File not found: yfinance_data\ISEE_data.csv
# Processing file: yfinance_data\ITCI_data.csv
# Columns found in yfinance_data\ITCI_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\ITI_data.csv
# Columns found in yfinance_data\ITI_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\ITOS_data.csv
# Columns found in yfinance_data\ITOS_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\IWC_data.csv
# Columns found in yfinance_data\IWC_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\IWM_data.csv
# Columns found in yfinance_data\IWM_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\JOY CN_data.csv
# Columns found in yfinance_data\JOY CN_data.csv: ['Price', 'Adj Close', 'Adj Close.1', 'Close', 'Close.1', 'High', 'High.1', 'Low', 'Low.1', 'Open', 'Open.1', 'Volume', 'Volume.1']
# Column 'Date' not found in yfinance_data\JOY CN_data.csv
# Processing file: yfinance_data\JSPR_data.csv
# Columns found in yfinance_data\JSPR_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\KA_data.csv
# Columns found in yfinance_data\KA_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\KCGI_data.csv
# Columns found in yfinance_data\KCGI_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\KDNY_data.csv
# File not found: yfinance_data\KDNY_data.csv
# Processing file: yfinance_data\KIII_data.csv
# File not found: yfinance_data\KIII_data.csv
# Processing file: yfinance_data\KIIIW_data.csv
# File not found: yfinance_data\KIIIW_data.csv
# Processing file: yfinance_data\KPTI_data.csv
# Columns found in yfinance_data\KPTI_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\KRTX_data.csv
# File not found: yfinance_data\KRTX_data.csv
# Processing file: yfinance_data\KURA_data.csv
# Columns found in yfinance_data\KURA_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\LABU_data.csv
# Columns found in yfinance_data\LABU_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\LEGN_data.csv
# Columns found in yfinance_data\LEGN_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\LIONW_data.csv
# File not found: yfinance_data\LIONW_data.csv
# Processing file: yfinance_data\LLY_data.csv
# Columns found in yfinance_data\LLY_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\LOCL_data.csv
# Columns found in yfinance_data\LOCL_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\LOKM_data.csv
# File not found: yfinance_data\LOKM_data.csv
# Processing file: yfinance_data\LQDA_data.csv
# Columns found in yfinance_data\LQDA_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\LRMR_data.csv
# Columns found in yfinance_data\LRMR_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\LXRX_data.csv
# Columns found in yfinance_data\LXRX_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\MACK_data.csv
# File not found: yfinance_data\MACK_data.csv
# Processing file: yfinance_data\MDGL_data.csv
# Columns found in yfinance_data\MDGL_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\MDH_data.csv
# File not found: yfinance_data\MDH_data.csv
# Processing file: yfinance_data\MDHAW_data.csv
# File not found: yfinance_data\MDHAW_data.csv
# Processing file: yfinance_data\MEOAW_data.csv
# File not found: yfinance_data\MEOAW_data.csv
# Processing file: yfinance_data\MIT_data.csv
# File not found: yfinance_data\MIT_data.csv
# Processing file: yfinance_data\MITGW_data.csv
# File not found: yfinance_data\MITGW_data.csv
# Processing file: yfinance_data\MOBV_data.csv
# File not found: yfinance_data\MOBV_data.csv
# Processing file: yfinance_data\MOBVW_data.csv
# File not found: yfinance_data\MOBVW_data.csv
# Processing file: yfinance_data\MRNA_data.csv
# Columns found in yfinance_data\MRNA_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\MRNS_data.csv
# Columns found in yfinance_data\MRNS_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\MRVI_data.csv
# Columns found in yfinance_data\MRVI_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\MSPR_data.csv
# File not found: yfinance_data\MSPR_data.csv
# Processing file: yfinance_data\MSTR_data.csv
# Columns found in yfinance_data\MSTR_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\MYOV_data.csv
# File not found: yfinance_data\MYOV_data.csv
# Processing file: yfinance_data\NAMSW_data.csv
# Columns found in yfinance_data\NAMSW_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\NEOG_data.csv
# Columns found in yfinance_data\NEOG_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\NGM_data.csv
# File not found: yfinance_data\NGM_data.csv
# Processing file: yfinance_data\NIHD_data.csv
# File not found: yfinance_data\NIHD_data.csv
# Processing file: yfinance_data\NIRWQ_data.csv
# File not found: yfinance_data\NIRWQ_data.csv
# Processing file: yfinance_data\NKTX_data.csv
# Columns found in yfinance_data\NKTX_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\NOVOB DC_data.csv
# Columns found in yfinance_data\NOVOB DC_data.csv: ['Price', 'Adj Close', 'Adj Close.1', 'Close', 'Close.1', 'High', 'High.1', 'Low', 'Low.1', 'Open', 'Open.1', 'Volume', 'Volume.1']
# Column 'Date' not found in yfinance_data\NOVOB DC_data.csv
# Processing file: yfinance_data\NRGV_data.csv
# Columns found in yfinance_data\NRGV_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\NTPIF_data.csv
# Columns found in yfinance_data\NTPIF_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\NUBI_data.csv
# File not found: yfinance_data\NUBI_data.csv
# Processing file: yfinance_data\NUBIW_data.csv
# File not found: yfinance_data\NUBIW_data.csv
# Processing file: yfinance_data\NVAX_data.csv
# Columns found in yfinance_data\NVAX_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\NVCN_data.csv
# File not found: yfinance_data\NVCN_data.csv
# Processing file: yfinance_data\NVCR_data.csv
# Columns found in yfinance_data\NVCR_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\NVTAQ_data.csv
# File not found: yfinance_data\NVTAQ_data.csv
# Processing file: yfinance_data\NWBO_data.csv
# Columns found in yfinance_data\NWBO_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\NXTC_data.csv
# Columns found in yfinance_data\NXTC_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\OABI_data.csv
# Columns found in yfinance_data\OABI_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\OBIO_data.csv
# Columns found in yfinance_data\OBIO_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\OCAX_data.csv
# Columns found in yfinance_data\OCAX_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\OCAXW_data.csv
# File not found: yfinance_data\OCAXW_data.csv
# Processing file: yfinance_data\OCUL_data.csv
# Columns found in yfinance_data\OCUL_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\OMI_data.csv
# Columns found in yfinance_data\OMI_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\ONFOW_data.csv
# File not found: yfinance_data\ONFOW_data.csv
# Processing file: yfinance_data\OPNT_data.csv
# File not found: yfinance_data\OPNT_data.csv
# Processing file: yfinance_data\ORKA_data.csv
# Columns found in yfinance_data\ORKA_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\ORMP_data.csv
# Columns found in yfinance_data\ORMP_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\OTIC_data.csv
# File not found: yfinance_data\OTIC_data.csv
# Processing file: yfinance_data\OYST_data.csv
# File not found: yfinance_data\OYST_data.csv
# Processing file: yfinance_data\PACX_data.csv
# File not found: yfinance_data\PACX_data.csv
# Processing file: yfinance_data\PCVX_data.csv
# Columns found in yfinance_data\PCVX_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\PFE_data.csv
# Columns found in yfinance_data\PFE_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\PHAT_data.csv
# Columns found in yfinance_data\PHAT_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\PLRX_data.csv
# Columns found in yfinance_data\PLRX_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\PLRXEUR XW_data.csv
# File not found: yfinance_data\PLRXEUR XW_data.csv
# Processing file: yfinance_data\PMGM_data.csv
# File not found: yfinance_data\PMGM_data.csv
# Processing file: yfinance_data\PMGMW_data.csv
# File not found: yfinance_data\PMGMW_data.csv
# Processing file: yfinance_data\PMVP_data.csv
# Columns found in yfinance_data\PMVP_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\PNT_data.csv
# File not found: yfinance_data\PNT_data.csv
# Processing file: yfinance_data\POSH_data.csv
# File not found: yfinance_data\POSH_data.csv
# Processing file: yfinance_data\PPH_data.csv
# Columns found in yfinance_data\PPH_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\PRTA_data.csv
# Columns found in yfinance_data\PRTA_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\PRTC LN_data.csv
# Columns found in yfinance_data\PRTC LN_data.csv: ['Price', 'Adj Close', 'Adj Close.1', 'Close', 'Close.1', 'High', 'High.1', 'Low', 'Low.1', 'Open', 'Open.1', 'Volume', 'Volume.1']
# Column 'Date' not found in yfinance_data\PRTC LN_data.csv
# Processing file: yfinance_data\PRVB_data.csv
# File not found: yfinance_data\PRVB_data.csv
# Processing file: yfinance_data\PSTH_data.csv
# File not found: yfinance_data\PSTH_data.csv
# Processing file: yfinance_data\PTCT_data.csv
# Columns found in yfinance_data\PTCT_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\PTGX_data.csv
# Columns found in yfinance_data\PTGX_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\PTWO_data.csv
# Columns found in yfinance_data\PTWO_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\PTWOW_data.csv
# File not found: yfinance_data\PTWOW_data.csv
# Processing file: yfinance_data\QQQ_data.csv
# Columns found in yfinance_data\QQQ_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\QURE_data.csv
# Columns found in yfinance_data\QURE_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\RARE_data.csv
# Columns found in yfinance_data\RARE_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\RCKT_data.csv
# Columns found in yfinance_data\RCKT_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\RCUS_data.csv
# Columns found in yfinance_data\RCUS_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\REGN_data.csv
# Columns found in yfinance_data\REGN_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\RETA_data.csv
# File not found: yfinance_data\RETA_data.csv
# Processing file: yfinance_data\REVRQ_data.csv
# File not found: yfinance_data\REVRQ_data.csv
# Processing file: yfinance_data\RHHBY_data.csv
# Columns found in yfinance_data\RHHBY_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\RLMD_data.csv
# Columns found in yfinance_data\RLMD_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\RMCO_data.csv
# Columns found in yfinance_data\RMCO_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\ROG_data.csv
# Columns found in yfinance_data\ROG_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\ROG SW_data.csv
# Columns found in yfinance_data\ROG SW_data.csv: ['Price', 'Adj Close', 'Adj Close.1', 'Close', 'Close.1', 'High', 'High.1', 'Low', 'Low.1', 'Open', 'Open.1', 'Volume', 'Volume.1']
# Column 'Date' not found in yfinance_data\ROG SW_data.csv
# Processing file: yfinance_data\ROIV_data.csv
# Columns found in yfinance_data\ROIV_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\RVMD_data.csv
# Columns found in yfinance_data\RVMD_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\RXDX_data.csv
# File not found: yfinance_data\RXDX_data.csv
# Processing file: yfinance_data\SAGE_data.csv
# Columns found in yfinance_data\SAGE_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\SAVA_data.csv
# Columns found in yfinance_data\SAVA_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\SBBP_data.csv
# File not found: yfinance_data\SBBP_data.csv
# Processing file: yfinance_data\SCPH_data.csv
# Columns found in yfinance_data\SCPH_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\SCRM_data.csv
# File not found: yfinance_data\SCRM_data.csv
# Processing file: yfinance_data\SDACW_data.csv
# File not found: yfinance_data\SDACW_data.csv
# Processing file: yfinance_data\SDGR_data.csv
# Columns found in yfinance_data\SDGR_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\SGEN_data.csv
# File not found: yfinance_data\SGEN_data.csv
# Processing file: yfinance_data\SIOX_data.csv
# File not found: yfinance_data\SIOX_data.csv
# Processing file: yfinance_data\SIRE_data.csv
# File not found: yfinance_data\SIRE_data.csv
# Processing file: yfinance_data\SLN_data.csv
# Columns found in yfinance_data\SLN_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\SLNO_data.csv
# Columns found in yfinance_data\SLNO_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\SPRO_data.csv
# Columns found in yfinance_data\SPRO_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\SPX Index_data.csv
# Columns found in yfinance_data\SPX Index_data.csv: ['Price', 'Adj Close', 'Adj Close.1', 'Close', 'Close.1', 'High', 'High.1', 'Low', 'Low.1', 'Open', 'Open.1', 'Volume', 'Volume.1']
# Column 'Date' not found in yfinance_data\SPX Index_data.csv
# Processing file: yfinance_data\SPXL_data.csv
# Columns found in yfinance_data\SPXL_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\SPY_data.csv
# Columns found in yfinance_data\SPY_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\SRPT_data.csv
# Columns found in yfinance_data\SRPT_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\SRTS_data.csv
# Columns found in yfinance_data\SRTS_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\SSPCF_data.csv
# File not found: yfinance_data\SSPCF_data.csv
# Processing file: yfinance_data\STSA_data.csv
# File not found: yfinance_data\STSA_data.csv
# Processing file: yfinance_data\SVFA_data.csv
# File not found: yfinance_data\SVFA_data.csv
# Processing file: yfinance_data\SVFB_data.csv
# File not found: yfinance_data\SVFB_data.csv
# Processing file: yfinance_data\SVRA_data.csv
# Columns found in yfinance_data\SVRA_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\SWAV_data.csv
# File not found: yfinance_data\SWAV_data.csv
# Processing file: yfinance_data\SWTX_data.csv
# Columns found in yfinance_data\SWTX_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\SYRE_data.csv
# Columns found in yfinance_data\SYRE_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\TAK_data.csv
# Columns found in yfinance_data\TAK_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\TBPH_data.csv
# Columns found in yfinance_data\TBPH_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\TCDAQ_data.csv
# File not found: yfinance_data\TCDAQ_data.csv
# Processing file: yfinance_data\TCRR_data.csv
# File not found: yfinance_data\TCRR_data.csv
# Processing file: yfinance_data\TELA_data.csv
# Columns found in yfinance_data\TELA_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\TGTX_data.csv
# Columns found in yfinance_data\TGTX_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\TIL_data.csv
# Columns found in yfinance_data\TIL_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\TNA_data.csv
# Columns found in yfinance_data\TNA_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\TRON_data.csv
# Columns found in yfinance_data\TRON_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\TVTX_data.csv
# Columns found in yfinance_data\TVTX_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\TXMD_data.csv
# Columns found in yfinance_data\TXMD_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\US3665052045 Pfd_data.csv
# Columns found in yfinance_data\US3665052045 Pfd_data.csv: ['Price', 'Adj Close', 'Adj Close.1', 'Close', 'Close.1', 'High', 'High.1', 'Low', 'Low.1', 'Open', 'Open.1', 'Volume', 'Volume.1']
# Column 'Date' not found in yfinance_data\US3665052045 Pfd_data.csv
# Processing file: yfinance_data\UVXY_data.csv
# Columns found in yfinance_data\UVXY_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\VCYT_data.csv
# Columns found in yfinance_data\VCYT_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\VDC_data.csv
# Columns found in yfinance_data\VDC_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\VERA_data.csv
# Columns found in yfinance_data\VERA_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\VERU_data.csv
# Columns found in yfinance_data\VERU_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\VERV_data.csv
# Columns found in yfinance_data\VERV_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\VKTX_data.csv
# Columns found in yfinance_data\VKTX_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\VOW3 GR_data.csv
# Columns found in yfinance_data\VOW3 GR_data.csv: ['Price', 'Adj Close', 'Adj Close.1', 'Close', 'Close.1', 'High', 'High.1', 'Low', 'Low.1', 'Open', 'Open.1', 'Volume', 'Volume.1']
# Column 'Date' not found in yfinance_data\VOW3 GR_data.csv
# Processing file: yfinance_data\VRDN_data.csv
# Columns found in yfinance_data\VRDN_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\VRNA_data.csv
# Columns found in yfinance_data\VRNA_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\VRTX_data.csv
# Columns found in yfinance_data\VRTX_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\VYX_data.csv
# Columns found in yfinance_data\VYX_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\WPCA_data.csv
# File not found: yfinance_data\WPCA_data.csv
# Processing file: yfinance_data\WPCAF_data.csv
# File not found: yfinance_data\WPCAF_data.csv
# Processing file: yfinance_data\WPCB_data.csv
# File not found: yfinance_data\WPCB_data.csv
# Processing file: yfinance_data\WPCBF_data.csv
# File not found: yfinance_data\WPCBF_data.csv
# Processing file: yfinance_data\WVE_data.csv
# Columns found in yfinance_data\WVE_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\XBI_data.csv
# Columns found in yfinance_data\XBI_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\XENE_data.csv
# Columns found in yfinance_data\XENE_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\XPOF_data.csv
# Columns found in yfinance_data\XPOF_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\ZGNX_data.csv
# File not found: yfinance_data\ZGNX_data.csv
# Processing file: yfinance_data\ZVSAW_data.csv
# File not found: yfinance_data\ZVSAW_data.csv
# Processing file: yfinance_data\ARE_data.csv
# Columns found in yfinance_data\ARE_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\ARKG_data.csv
# Columns found in yfinance_data\ARKG_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\AXSM_data.csv
# Columns found in yfinance_data\AXSM_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\BCLI_data.csv
# Columns found in yfinance_data\BCLI_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\CANO_data.csv
# File not found: yfinance_data\CANO_data.csv
# Processing file: yfinance_data\CETUU_data.csv
# File not found: yfinance_data\CETUU_data.csv
# Processing file: yfinance_data\CVM_data.csv
# Columns found in yfinance_data\CVM_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\DCTH_data.csv
# Columns found in yfinance_data\DCTH_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\DXCM_data.csv
# Columns found in yfinance_data\DXCM_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\ESAIY_data.csv
# Columns found in yfinance_data\ESAIY_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\FULC_data.csv
# Columns found in yfinance_data\FULC_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\FUSN_data.csv
# File not found: yfinance_data\FUSN_data.csv
# Processing file: yfinance_data\GEVO_data.csv
# ...
# Column 'Date' not found in yfinance_data\MDNA CN_data.csv
# Processing file: yfinance_data\ELDN_data.csv
# Columns found in yfinance_data\ELDN_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\ABEO_data.csv
# Columns found in yfinance_data\ABEO_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\CUE_data.csv
# Columns found in yfinance_data\CUE_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\SMIN_data.csv
# Columns found in yfinance_data\SMIN_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\SNSE_data.csv
# Columns found in yfinance_data\SNSE_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\XLO_data.csv
# Columns found in yfinance_data\XLO_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\NAMS_data.csv
# Columns found in yfinance_data\NAMS_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\ENGN_data.csv
# Columns found in yfinance_data\ENGN_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\SUPN_data.csv
# Columns found in yfinance_data\SUPN_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\HLVX_data.csv
# Columns found in yfinance_data\HLVX_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\TCRX_data.csv
# Columns found in yfinance_data\TCRX_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\AURA_data.csv
# Columns found in yfinance_data\AURA_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\KYTX_data.csv
# Columns found in yfinance_data\KYTX_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\KALA_data.csv
# Columns found in yfinance_data\KALA_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\ATRA_data.csv
# Columns found in yfinance_data\ATRA_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\CAPR UR_data.csv
# Columns found in yfinance_data\CAPR UR_data.csv: ['Price', 'Adj Close', 'Adj Close.1', 'Close', 'Close.1', 'High', 'High.1', 'Low', 'Low.1', 'Open', 'Open.1', 'Volume', 'Volume.1']
# Column 'Date' not found in yfinance_data\CAPR UR_data.csv
# Processing file: yfinance_data\UNH_data.csv
# Columns found in yfinance_data\UNH_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\BNTX_data.csv
# Columns found in yfinance_data\BNTX_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\MNMD_data.csv
# Columns found in yfinance_data\MNMD_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\FIGXX_data.csv
# File not found: yfinance_data\FIGXX_data.csv
# Processing file: yfinance_data\LIVN_data.csv
# Columns found in yfinance_data\LIVN_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\NUVB_data.csv
# Columns found in yfinance_data\NUVB_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\KRRO_data.csv
# Columns found in yfinance_data\KRRO_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\GRAL_data.csv
# Columns found in yfinance_data\GRAL_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\PCSC_data.csv
# Columns found in yfinance_data\PCSC_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\PRTC_data.csv
# Columns found in yfinance_data\PRTC_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\RZLT_data.csv
# Columns found in yfinance_data\RZLT_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\VXRT_data.csv
# Columns found in yfinance_data\VXRT_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\ATR_data.csv
# Columns found in yfinance_data\ATR_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\INVA_data.csv
# Columns found in yfinance_data\INVA_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\ETON_data.csv
# Columns found in yfinance_data\ETON_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\TNDM_data.csv
# Columns found in yfinance_data\TNDM_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\RGLS_data.csv
# Columns found in yfinance_data\RGLS_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\TEM_data.csv
# Columns found in yfinance_data\TEM_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\CASI_data.csv
# Columns found in yfinance_data\CASI_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\22Z TH_data.csv
# Columns found in yfinance_data\22Z TH_data.csv: ['Price', 'Adj Close', 'Adj Close.1', 'Close', 'Close.1', 'High', 'High.1', 'Low', 'Low.1', 'Open', 'Open.1', 'Volume', 'Volume.1']
# Column 'Date' not found in yfinance_data\22Z TH_data.csv
# Processing file: yfinance_data\2268338D_data.csv
# File not found: yfinance_data\2268338D_data.csv
# Processing file: yfinance_data\CNH Curncy_data.csv
# Columns found in yfinance_data\CNH Curncy_data.csv: ['Price', 'Adj Close', 'Adj Close.1', 'Close', 'Close.1', 'High', 'High.1', 'Low', 'Low.1', 'Open', 'Open.1', 'Volume', 'Volume.1']
# Column 'Date' not found in yfinance_data\CNH Curncy_data.csv
# Processing file: yfinance_data\LXEO_data.csv
# Columns found in yfinance_data\LXEO_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\SANA_data.csv
# Columns found in yfinance_data\SANA_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\ZURAW_data.csv
# File not found: yfinance_data\ZURAW_data.csv
# Processing file: yfinance_data\ILMN_data.csv
# Columns found in yfinance_data\ILMN_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\BSX_data.csv
# Columns found in yfinance_data\BSX_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\NTRA_data.csv
# Columns found in yfinance_data\NTRA_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\FIE GY_data.csv
# File not found: yfinance_data\FIE GY_data.csv
# Processing file: yfinance_data\FTRE_data.csv
# Columns found in yfinance_data\FTRE_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\LONN SW_data.csv
# Columns found in yfinance_data\LONN SW_data.csv: ['Price', 'Adj Close', 'Adj Close.1', 'Close', 'Close.1', 'High', 'High.1', 'Low', 'Low.1', 'Open', 'Open.1', 'Volume', 'Volume.1']
# Column 'Date' not found in yfinance_data\LONN SW_data.csv
# Processing file: yfinance_data\ALM SM_data.csv
# Columns found in yfinance_data\ALM SM_data.csv: ['Price', 'Adj Close', 'Adj Close.1', 'Close', 'Close.1', 'High', 'High.1', 'Low', 'Low.1', 'Open', 'Open.1', 'Volume', 'Volume.1']
# Column 'Date' not found in yfinance_data\ALM SM_data.csv
# Processing file: yfinance_data\PIRS_data.csv
# Columns found in yfinance_data\PIRS_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\ALGN_data.csv
# Columns found in yfinance_data\ALGN_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\DHR_data.csv
# Columns found in yfinance_data\DHR_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\STAA_data.csv
# Columns found in yfinance_data\STAA_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\TMO_data.csv
# Columns found in yfinance_data\TMO_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\PEPG_data.csv
# Columns found in yfinance_data\PEPG_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\TRDA_data.csv
# Columns found in yfinance_data\TRDA_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\US15117F6097 Pfd_data.csv
# Columns found in yfinance_data\US15117F6097 Pfd_data.csv: ['Price', 'Adj Close', 'Adj Close.1', 'Close', 'Close.1', 'High', 'High.1', 'Low', 'Low.1', 'Open', 'Open.1', 'Volume', 'Volume.1']
# Column 'Date' not found in yfinance_data\US15117F6097 Pfd_data.csv
# Processing file: yfinance_data\ENTA_data.csv
# Columns found in yfinance_data\ENTA_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\SDZ SW_data.csv
# Columns found in yfinance_data\SDZ SW_data.csv: ['Price', 'Adj Close', 'Adj Close.1', 'Close', 'Close.1', 'High', 'High.1', 'Low', 'Low.1', 'Open', 'Open.1', 'Volume', 'Volume.1']
# Column 'Date' not found in yfinance_data\SDZ SW_data.csv
# Processing file: yfinance_data\THRD_data.csv
# Columns found in yfinance_data\THRD_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\0968190D_data.csv
# File not found: yfinance_data\0968190D_data.csv
# Processing file: yfinance_data\ADGM_data.csv
# Columns found in yfinance_data\ADGM_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\ALXO_data.csv
# Columns found in yfinance_data\ALXO_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\AAM/U_data.csv
# File not found: yfinance_data\AAM/U_data.csv
# Processing file: yfinance_data\ABIO_data.csv
# Columns found in yfinance_data\ABIO_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\FST_data.csv
# File not found: yfinance_data\FST_data.csv
# Processing file: yfinance_data\MKDWW_data.csv
# File not found: yfinance_data\MKDWW_data.csv
# Processing file: yfinance_data\MKDW_data.csv
# Columns found in yfinance_data\MKDW_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\PRME_data.csv
# Columns found in yfinance_data\PRME_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\HROW_data.csv
# Columns found in yfinance_data\HROW_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\ADXN SW_data.csv
# Columns found in yfinance_data\ADXN SW_data.csv: ['Price', 'Adj Close', 'Adj Close.1', 'Close', 'Close.1', 'High', 'High.1', 'Low', 'Low.1', 'Open', 'Open.1', 'Volume', 'Volume.1']
# Column 'Date' not found in yfinance_data\ADXN SW_data.csv
# Processing file: yfinance_data\TENX_data.csv
# Columns found in yfinance_data\TENX_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\TNXP_data.csv
# Columns found in yfinance_data\TNXP_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\ALTR_data.csv
# Columns found in yfinance_data\ALTR_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\RTYU4 Index_data.csv
# Columns found in yfinance_data\RTYU4 Index_data.csv: ['Price', 'Adj Close', 'Adj Close.1', 'Close', 'Close.1', 'High', 'High.1', 'Low', 'Low.1', 'Open', 'Open.1', 'Volume', 'Volume.1']
# Column 'Date' not found in yfinance_data\RTYU4 Index_data.csv
# Processing file: yfinance_data\GALT_data.csv
# Columns found in yfinance_data\GALT_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\MRKR_data.csv
# Columns found in yfinance_data\MRKR_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\AITR_data.csv
# Columns found in yfinance_data\AITR_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\AITRR_data.csv
# File not found: yfinance_data\AITRR_data.csv
# Processing file: yfinance_data\BKHA_data.csv
# Columns found in yfinance_data\BKHA_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\BKHAR_data.csv
# File not found: yfinance_data\BKHAR_data.csv
# Processing file: yfinance_data\CTNM_data.csv
# Columns found in yfinance_data\CTNM_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\IROH_data.csv
# Columns found in yfinance_data\IROH_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\IROHR_data.csv
# File not found: yfinance_data\IROHR_data.csv
# Processing file: yfinance_data\IROHW_data.csv
# File not found: yfinance_data\IROHW_data.csv
# Processing file: yfinance_data\JVSA_data.csv
# Columns found in yfinance_data\JVSA_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\JVSAR_data.csv
# File not found: yfinance_data\JVSAR_data.csv
# Processing file: yfinance_data\ME_data.csv
# Columns found in yfinance_data\ME_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\MNPR_data.csv
# Columns found in yfinance_data\MNPR_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\NNAG_data.csv
# Columns found in yfinance_data\NNAG_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\NNAGR_data.csv
# File not found: yfinance_data\NNAGR_data.csv
# Processing file: yfinance_data\NNAGW_data.csv
# File not found: yfinance_data\NNAGW_data.csv
# Processing file: yfinance_data\GUBRA DC_data.csv
# Columns found in yfinance_data\GUBRA DC_data.csv: ['Price', 'Adj Close', 'Adj Close.1', 'Close', 'Close.1', 'High', 'High.1', 'Low', 'Low.1', 'Open', 'Open.1', 'Volume', 'Volume.1']
# Column 'Date' not found in yfinance_data\GUBRA DC_data.csv
# Processing file: yfinance_data\VIGL_data.csv
# Columns found in yfinance_data\VIGL_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\ANRO_data.csv
# Columns found in yfinance_data\ANRO_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\TNGX_data.csv
# Columns found in yfinance_data\TNGX_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\NVS_data.csv
# Columns found in yfinance_data\NVS_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\GSK_data.csv
# Columns found in yfinance_data\GSK_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Processing file: yfinance_data\SYRS_data.csv
# Columns found in yfinance_data\SYRS_data.csv: ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# Final adjusted close DataFrame:
#         Date  Ticker    Adj_Close
# 0 2018-01-01  4502.T  4700.279785
# 1 2018-01-02  4502.T  4700.279785
# 2 2018-01-03  4502.T  4700.279785
# 3 2018-01-04  4502.T  4784.724121
# 4 2018-01-05  4502.T  4822.908691

# %%
# Assuming df and adjusted_close_df are already defined
# Merging df with adjusted_close_df on 'Ticker' and 'Date' using a left join
merged_df = pd.merge(df, adjusted_close_df, on=['Ticker', 'Date'], how='left')

# Drop all rows with any NaN values
cleaned_df = merged_df.dropna()

# Display the first few rows of the cleaned DataFrame for verification
print("Cleaned DataFrame (with no NaN values):")
print(cleaned_df.head())
# Out:
# Cleaned DataFrame (with no NaN values):
#         Date  Ticker       AUM BOD       AUM EOD       P&L   P&L (%)  \
# 0 2023-01-31  4502.T  7.268115e+07  7.561933e+07   4156.44  0.000057
# 1 2023-01-31  4523.T  7.268115e+07  7.561933e+07  30633.20  0.000421
# 4 2023-01-31    AADI  7.268115e+07  7.561933e+07   -974.67 -0.000013
# 6 2023-01-31    ABBV  7.268115e+07  7.561933e+07 -13906.36 -0.000191
# 7 2023-01-31    ABCL  7.268115e+07  7.561933e+07    655.10  0.000009
#
#              Net   Net (%)          Gross  Gross(%)  Market Value  \
# 0  723114.700000  0.009563  723114.700000  0.009563     723114.70
# 1   92382.190000  0.001222   92382.190000  0.001222      92382.19
# 4   50196.076239  0.000664   50196.076239  0.000664      32649.00
# 6  886500.000000  0.011723  886500.000000  0.011723     886500.00
# 7   -2365.001923 -0.000031   17446.862015  0.000231      -5280.00
#
#    Market Value (%)  Returns_Percent  Mkt-RF   SMB   HML   RMW   CMA     RF  \
# 0          0.009563         0.000057    1.58  0.94 -0.07 -0.06 -0.51  0.017
# 1          0.001222         0.000421    1.58  0.94 -0.07 -0.06 -0.51  0.017
# 4          0.000432        -0.000013    1.58  0.94 -0.07 -0.06 -0.51  0.017
# 6          0.011723        -0.000191    1.58  0.94 -0.07 -0.06 -0.51  0.017
# 7         -0.000070         0.000009    1.58  0.94 -0.07 -0.06 -0.51  0.017
#
#    XBI_Daily_Returns  NBI_Daily_Returns  IWM_Daily_Returns    Adj_Close
# 0           0.024286           0.020666           0.011836  3754.602783
# 1           0.024286           0.020666           0.011836  7641.306152
# 4           0.024286           0.020666           0.011836    12.620000
# 6           0.024286           0.020666           0.011836   139.411575
# 7           0.024286           0.020666           0.011836    10.530000

# %%
def calculate_factor_exposure(cleaned_df, date):
    # Filter the DataFrame for the specific date
    filtered_df = cleaned_df[cleaned_df['Date'] == date]
    
    # Calculate the weighted exposure for each factor
    weights = filtered_df['Market Value (%)']
    print(weights)
    factor_columns = ['Mkt-RF', 'SMB', 'HML', 'RMW', 'CMA']
    exposure = (filtered_df[factor_columns].T * weights).T.sum()
    
    return exposure

# Example usage
date = '2023-01-31'
portfolio_exposure = calculate_factor_exposure(cleaned_df, date)
print(portfolio_exposure)
# Out:
# 0      0.009563
# 1      0.001222
# 4      0.000432
# 6      0.011723
# 7     -0.000070
#          ...
# 325   -0.000195
# 332    0.000130
# 333   -0.007111
# 334   -0.000081
# 335   -0.000073
# Name: Market Value (%), Length: 164, dtype: float64
# Mkt-RF    0.268427
# SMB       0.159697
# HML      -0.011892
# RMW      -0.010193
# CMA      -0.086644
# dtype: float64

# %% [markdown]
# ### Function Purpose
# The function `calculate_factor_exposure` helps to figure out how much different financial factors (like market risk, size, and value) affect a group of investments on a specific date.
#
# ### How It Works
#
# 1. **Filtering Data**:
#    - First, it looks at the investment data for a specific date. Imagine you have a big notebook with daily records, and you just want to open the page for January 31, 2023.
#
# 2. **Getting Weights**:
#    - Next, it takes the "Market Value (%)" for each investment on that date. Think of this as how much each investment is worth compared to the total. For example, if one investment is worth 10% of the total, it will have a weight of 0.10.
#
# 3. **Defining Factors**:
#    - It lists out some key financial factors that affect returns, such as:
#      - **Mkt-RF**: How much the market earns beyond the risk-free rate (like the return on a safe investment).
#      - **SMB**: Smaller companies compared to larger ones.
#      - **HML**: Companies that are considered "cheap" versus those that are "expensive."
#      - **RMW**: Companies that are more profitable versus less profitable.
#      - **CMA**: Companies that invest conservatively versus aggressively.
#
# 4. **Calculating Exposure**:
#    - For each factor, it multiplies the factor's value by the investment's weight. This tells you how much each investment contributes to each factor, based on its size.
#    - Then, it adds all those contributions together for each factor to see the total exposure to that factor.
#
# ### Final Result
# - The function returns a summary showing how much exposure the investments have to each of those financial factors on that specific date. This helps investors understand where their risks and opportunities lie in relation to market movements and investment styles.
#
# In essence, it’s like saying, "For this day, how much do our investments lean toward these different factors?"
