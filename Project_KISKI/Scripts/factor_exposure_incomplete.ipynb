# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import getFamaFrenchFactors as gff

# Set plot style for better aesthetics
sns.set(style="whitegrid")

# Step 1: Load and preprocess portfolio data
df_daily_ticker = pd.read_excel(r"C:\Users\MukeshwaranBaskaran\Downloads\Project_KISKI\Data\KISKI_Data_PositionLevel_Daily_Ticker_Net.xlsx")
df_daily_ticker.columns = df_daily_ticker.columns.str.strip()
df_daily_ticker.rename(columns={"Trade Dt": "Date"}, inplace=True)

# Ensure 'Date' is in datetime format
df_daily_ticker['Date'] = pd.to_datetime(df_daily_ticker['Date'])

# Step 2: Forward fill missing dates
df_daily_ticker.sort_values('Date', inplace=True)
df_daily_ticker['Date'] = df_daily_ticker['Date'].ffill()

# Now df_daily_ticker has forward-filled dates
df_daily_ticker.head()
# Out:
#           Date       Group       AUM BOD       AUM EOD         P&L   P&L (%)  \
# 0   2019-03-31        AKBA  6.200000e+06  6.398866e+06   225.22000  0.000036
# 45  2019-04-30        AABA  6.398866e+06  6.687844e+06  2185.00000  0.000341
# 127 2019-05-31        AABA  6.687844e+06  6.836094e+06  3422.40685  0.000512
# 216 2019-06-30  6EN9 Index  6.836094e+06  6.915215e+06  9337.95000  0.001366
# 291 2019-07-31  6EN9 Index  6.915215e+06  7.133661e+06 -7793.25000 -0.001127
#
#             Net       Net (%)       Gross      Gross(%)  Market Value  \
# 0    24570.0000  3.839743e-03  24570.0000  3.839743e-03    24570.0000
# 45   75390.0000  1.127269e-02  75390.0000  1.127269e-02    75390.0000
# 127         NaN           NaN         NaN           NaN           NaN
# 216      5.6955  8.236187e-07      5.6955  8.236187e-07        5.6955
# 291         NaN           NaN         NaN           NaN           NaN
#
#      Market Value (%)
# 0        3.839743e-03
# 45       1.127269e-02
# 127               NaN
# 216      8.236187e-07
# 291               NaN

# %%
df_daily_factors = pd.read_csv(r"C:\Users\MukeshwaranBaskaran\Downloads\Project_KISKI\Data\F-F_Research_Data_5_Factors_2x3_daily.CSV")
df_daily_factors.head()
# Out:
#        Date  Mkt-RF   SMB   HML   RMW   CMA     RF
# 0  19630701   -0.67  0.02 -0.35  0.03  0.13  0.012
# 1  19630702    0.79 -0.28  0.28 -0.08 -0.21  0.012
# 2  19630703    0.63 -0.18 -0.10  0.13 -0.25  0.012
# 3  19630705    0.40  0.09 -0.28  0.07 -0.30  0.012
# 4  19630708   -0.63  0.07 -0.20 -0.27  0.06  0.012

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import yfinance as yf

# Load factor data
df_daily_factors = pd.read_csv(r"C:\Users\MukeshwaranBaskaran\Downloads\Project_KISKI\Data\F-F_Research_Data_5_Factors_2x3_daily.CSV")
df_daily_factors['Date'] = pd.to_datetime(df_daily_factors['Date'], format='%Y%m%d')

# Load portfolio data
df_daily_ticker = pd.read_excel(r"C:\Users\MukeshwaranBaskaran\Downloads\Project_KISKI\Data\KISKI_Data_PositionLevel_Daily_Ticker_Net.xlsx")
df_daily_ticker.columns = df_daily_ticker.columns.str.strip()
df_daily_ticker.rename(columns={"Trade Dt": "Date"}, inplace=True)
df_daily_ticker['Date'] = pd.to_datetime(df_daily_ticker['Date'])

# Handle missing values by forward filling
df_daily_ticker.fillna(method='ffill', inplace=True)

# Fetch historical prices using yfinance
groups = df_daily_ticker['Group'].unique()
tickers = " ".join(groups)  # Join tickers with space or use "," for comma

# Download adjusted closing prices
prices_data = yf.download(tickers, start="2023-01-01", end="2023-12-31")['Adj Close']

# Calculate daily returns for each group
returns_data = prices_data.pct_change().dropna()

# Merge portfolio data with factor data on 'Date'
df_combined = pd.merge(df_daily_ticker, df_daily_factors, on='Date', how='inner')

# Add returns to the combined dataframe
df_combined = df_combined.merge(returns_data, left_on=['Date', 'Group'], right_index=True, how='left')
df_combined.rename(columns={group: 'Return' for group in groups}, inplace=True)

# Define a function to calculate betas for each group using regression
def calculate_beta(stock_returns, factor_returns):
    X = sm.add_constant(factor_returns)
    model = sm.OLS(stock_returns, X).fit()
    return model.params[1:]  # Return betas excluding intercept

# Calculate betas for each group in the portfolio
betas = {}
for group in df_combined['Group'].unique():
    stock_data = df_combined[df_combined['Group'] == group]
    betas[group] = calculate_beta(stock_data['Return'].dropna(), stock_data[['Mkt-RF', 'SMB', 'HML', 'RMW', 'CMA']])

# Calculate position-level beta exposures
df_combined['Net Exposure'] = df_combined['Shares'] * df_combined['Price']
df_combined['Beta Exposure'] = df_combined.apply(
    lambda row: np.dot(betas[row['Group']], row[['Mkt-RF', 'SMB', 'HML', 'RMW', 'CMA']]) * row['Net Exposure'], axis=1)

# Aggregate to get portfolio-level factor exposures
portfolio_exposure = df_combined.groupby('Date')['Beta Exposure'].sum()

print(portfolio_exposure.head())
# Out:
# C:\Users\MukeshwaranBaskaran\AppData\Local\Temp\ipykernel_1692\857452612.py:17: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_daily_ticker.fillna(method='ffill', inplace=True)
# [                       1%                       ]  14 of 2505 completedFailed to get ticker 'MIT/U' reason: Expecting value: line 1 column 1 (char 0)
# [                       1%                       ]  25 of 2505 completedCould not get exchangeTimezoneName for ticker '' reason: list index out of range
# [*                      2%                       ]  51 of 2505 completedFailed to get ticker 'DMYQ/U' reason: Expecting value: line 1 column 1 (char 0)
# [**                     5%                       ]  123 of 2505 completedFailed to get ticker 'OPA/WS' reason: Expecting value: line 1 column 1 (char 0)
# [***                    7%                       ]  165 of 2505 completedFailed to get ticker 'ZGN/WS' reason: Expecting value: line 1 column 1 (char 0)
# [****                   9%                       ]  221 of 2505 completedFailed to get ticker 'PSTH/U' reason: Expecting value: line 1 column 1 (char 0)
# [****                   9%                       ]  228 of 2505 completedFailed to get ticker 'NUVB/WS' reason: Expecting value: line 1 column 1 (char 0)
# [*****                 10%                       ]  249 of 2505 completedFailed to get ticker 'HZAC/WS' reason: Expecting value: line 1 column 1 (char 0)
# [*****                 11%                       ]  276 of 2505 completedFailed to get ticker 'RCOR/WS' reason: Expecting value: line 1 column 1 (char 0)
# [******                13%                       ]  330 of 2505 completedFailed to get ticker 'IFIN/WS' reason: Expecting value: line 1 column 1 (char 0)
# [*********             18%                       ]  454 of 2505 completedFailed to get ticker 'QS/WS' reason: Expecting value: line 1 column 1 (char 0)
# [************          26%                       ]  659 of 2505 completedFailed to get ticker 'LGF/B' reason: Expecting value: line 1 column 1 (char 0)
# [*************         28%                       ]  712 of 2505 completedFailed to get ticker 'WPCA/U' reason: Expecting value: line 1 column 1 (char 0)
# [**************        29%                       ]  726 of 2505 completedFailed to get ticker 'BRK/B' reason: Expecting value: line 1 column 1 (char 0)
# [**************        30%                       ]  761 of 2505 completedFailed to get ticker 'BP/' reason: Expecting value: line 1 column 1 (char 0)
# [***************       32%                       ]  806 of 2505 completedFailed to get ticker 'BBAI/WS' reason: Expecting value: line 1 column 1 (char 0)
# [****************      34%                       ]  845 of 2505 completedFailed to get ticker 'CVII/U' reason: Expecting value: line 1 column 1 (char 0)
# [****************      34%                       ]  848 of 2505 completedFailed to get ticker 'IPOA/U' reason: Expecting value: line 1 column 1 (char 0)
# [*****************     36%                       ]  891 of 2505 completedFailed to get ticker 'AEON/WS' reason: Expecting value: line 1 column 1 (char 0)
# [********************  41%                       ]  1022 of 2505 completedFailed to get ticker 'AAM/U' reason: Expecting value: line 1 column 1 (char 0)
# [********************  42%                       ]  1054 of 2505 completedFailed to get ticker 'NBA/U' reason: Expecting value: line 1 column 1 (char 0)
# [********************* 43%                       ]  1085 of 2505 completedFailed to get ticker 'CCVI/U' reason: Expecting value: line 1 column 1 (char 0)
# [********************* 44%                       ]  1098 of 2505 completedFailed to get ticker 'PSTH/WS' reason: Expecting value: line 1 column 1 (char 0)
# [********************* 44%                       ]  1109 of 2505 completedFailed to get ticker 'FZT/WS' reason: Expecting value: line 1 column 1 (char 0)
# [**********************46%                       ]  1145 of 2505 completedFailed to get ticker 'HZON/WS' reason: Expecting value: line 1 column 1 (char 0)
# [**********************48%                       ]  1204 of 2505 completedFailed to get ticker 'OPA/U' reason: Expecting value: line 1 column 1 (char 0)
# [**********************50%                       ]  1244 of 2505 completedFailed to get ticker 'BBLN/WS' reason: Expecting value: line 1 column 1 (char 0)
# [**********************52%                       ]  1293 of 2505 completedFailed to get ticker 'PL/WS' reason: Expecting value: line 1 column 1 (char 0)
# [**********************59%***                    ]  1483 of 2505 completedFailed to get ticker 'TWNT/U' reason: Expecting value: line 1 column 1 (char 0)
# [**********************61%****                   ]  1521 of 2505 completedFailed to get ticker 'WPCB/U' reason: Expecting value: line 1 column 1 (char 0)
# [**********************64%******                 ]  1614 of 2505 completedFailed to get ticker '09/28/27' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'LGVW/U' reason: Expecting value: line 1 column 1 (char 0)
# [**********************66%*******                ]  1663 of 2505 completedFailed to get ticker '01/19/24' reason: Expecting value: line 1 column 1 (char 0)
# [**********************66%*******                ]  1664 of 2505 completedFailed to get ticker 'LHC/U' reason: Expecting value: line 1 column 1 (char 0)
# [**********************68%********               ]  1705 of 2505 completedFailed to get ticker 'IFIN/U' reason: Expecting value: line 1 column 1 (char 0)
# [**********************70%*********              ]  1752 of 2505 completedFailed to get ticker 'VYGG/WS' reason: Expecting value: line 1 column 1 (char 0)
# [**********************77%************           ]  1931 of 2505 completedFailed to get ticker 'SFTW/WS' reason: Expecting value: line 1 column 1 (char 0)
# [**********************79%*************          ]  1979 of 2505 completedFailed to get ticker 'MDH/U' reason: Expecting value: line 1 column 1 (char 0)
# [**********************80%*************          ]  2008 of 2505 completedFailed to get ticker 'TRCA/WS' reason: Expecting value: line 1 column 1 (char 0)
# [**********************85%****************       ]  2140 of 2505 completedFailed to get ticker 'PANA/U' reason: Expecting value: line 1 column 1 (char 0)
# [**********************89%******************     ]  2220 of 2505 completedFailed to get ticker 'FST/WS' reason: Expecting value: line 1 column 1 (char 0)
# [**********************90%******************     ]  2264 of 2505 completedFailed to get ticker 'LGF/A' reason: Expecting value: line 1 column 1 (char 0)
# [**********************91%*******************    ]  2288 of 2505 completedFailed to get ticker 'LOKM/U' reason: Expecting value: line 1 column 1 (char 0)
# [**********************92%*******************    ]  2316 of 2505 completedFailed to get ticker 'NFNT/U' reason: Expecting value: line 1 column 1 (char 0)
# [**********************93%********************   ]  2327 of 2505 completedFailed to get ticker 'DM/WS' reason: Expecting value: line 1 column 1 (char 0)
# [**********************93%********************   ]  2334 of 2505 completedFailed to get ticker 'IIAC/WS' reason: Expecting value: line 1 column 1 (char 0)
# [**********************94%********************   ]  2345 of 2505 completedFailed to get ticker 'DNA/WS' reason: Expecting value: line 1 column 1 (char 0)
# [**********************94%********************   ]  2361 of 2505 completedFailed to get ticker 'IPOA/WS' reason: Expecting value: line 1 column 1 (char 0)
# [**********************95%*********************  ]  2388 of 2505 completedFailed to get ticker 'YAC/WS' reason: Expecting value: line 1 column 1 (char 0)
# [**********************96%*********************  ]  2400 of 2505 completedFailed to get ticker 'IPOD/U' reason: Expecting value: line 1 column 1 (char 0)
# [**********************99%***********************]  2475 of 2505 completedFailed to get ticker 'IPOB/WS' reason: Expecting value: line 1 column 1 (char 0)
# [*********************100%***********************]  2505 of 2505 completed
#
# 844 Failed downloads:
# ['NGMS', 'LOKM', 'MIT/U', 'LAAA', 'NIRLQ', 'RKLYQ', 'TRHC', 'TBA', 'IPOB', 'TARO', 'GIIXW', 'DMYQ/U', 'MOBVW', 'ZGNX', 'POL', 'DCRN', 'MONCW', 'EQRX', 'PFPT', 'AVRXX', 'SBTX', 'BENEU', 'USDLEGALFEE', 'SSUTF', 'ERICB', 'NKLAW', 'PPGN', 'DTLA', 'ESU0', '1893407D', 'NSTGQ', 'ARYD', 'OPA/WS', '2411443D', 'SSPCF', 'PRTK', 'FPAC', 'PS', 'IPOC', 'TPGY', 'ECN21', 'BOXDQ', 'BKI', 'ABGI', 'ZGN/WS', 'NUBIU', 'SMTA', 'LUXA', 'CLF3', 'ALTU', 'PLXPQ', 'OYST', 'LVGO', 'AIMC', 'ADER', 'PSTH/U', 'PLAN', 'DICE', 'NUVB/WS', 'ESSCW', 'FIT', 'SAIL', 'IS', 'SRNEQ', 'SJR', 'HZAC/WS', 'ETAC', 'CSPR', 'VIVO', 'TCRR', '4523', 'FSTX', 'RCOR/WS', 'ARQL', 'CRSAW', 'RDBX', 'NGV22', 'ARNC', 'DDMX', 'CRHC', 'EAR', 'SPPI', 'BMY-R', 'TTPH', 'ICVX', 'VNE', 'ACAXU', 'DCTHWS', 'FINM', 'FBC', 'CTXS', 'IFIN/WS', 'AJAX', 'VALE3', 'RADI', 'KLR', 'EDZ2', 'BLI', 'RTYU4', 'HK', 'SIMTCZ', 'AGC', 'HCARW', 'ASPC', 'ECJ20', 'RARX', 'ARYBU', 'VORBQ', 'CLGX', 'GUBRA', 'ADOCW', 'PRVL', 'TL0', '2223637D', '4503', 'GRCL', 'PRNB', 'RENN', 'DISCB', 'ALXN', 'ARYAU', 'TYZ21', 'KNTE', 'PSTH', 'DEN', 'ARVL', 'PAFO', 'SRNGU', '1368826D', 'QS/WS', '1480990D', 'RKET', 'CBAY', 'OZON', 'MNKTQ', 'ADOCU', 'ZYNE', 'ATNXQ', 'FINMU', 'MIMO', 'MTOR', 'PTRAQ', 'WARRANTS', 'KAHC', 'RCOR', '0968190D', 'SAIIU', 'MDHAW', '1557717D', 'NVCN', 'ACH', 'JP', 'KDNY', '4502', 'MOBV', 'FLFV', 'FFF23', 'ICPT', 'EFHTR', 'RLGY', 'VMW', 'ZY', 'HIBB', 'AGN', 'MOBVU', 'POLY', 'VOW3', 'ESSC', 'VSLR', 'AVYAQ', 'STML', 'HZAC', 'HDFCB', 'DRNA', 'PING', 'SCHN', 'ECH22', 'DCP', 'KLAQW', 'FIXX', 'BFT', 'IMMU', 'AMRSQ', 'LGF/B', 'AGCWW', 'JOFFW', 'CCXI', 'ACAH', 'OSG', 'PLF1', '$4.215', 'VVABALV', 'WPCA/U', 'COWN', 'IMGO', 'PRVB', 'SCPE', 'BRK/B', 'OPNT', 'CNR', 'AERI', 'AEACU', 'ATRS', 'DCPH', 'MEOAW', 'PDLI', '(DELISTED)', 'AQUA', 'BP/', 'CETU', 'CGGZ-U', 'VIFN', 'LEGOU', '2268338D', 'MNTV', 'FTSV', 'TRIL', '2152294D', 'BBAI/WS', 'IRNTQ', 'WORK', 'ID', 'AMAM', 'ROVRW', 'GRSV', 'ADOCR', 'CIIC', '6EV9', '1426984D', 'CXO', 'CVII/U', 'IPOA/U', 'MIT', 'AYLA', 'VLDR', '7974', 'AKLI', 'NQH0', 'RMO', 'MAXR', 'PLRXEUR', 'ONCE', 'SUMO', 'LHAA', 'NGM', 'XBJ22', 'AEON/WS', 'TVTY', 'BRN9', 'CBAI', 'RICO', 'ACC', 'CRU', '1879928D', 'HHC', 'VTIQ', 'UROV', 'BMW3', 'ESU9', 'FLFVU', 'IAA', 'CELG', 'FTOC', 'STSA', 'ALPN', 'RXDX', 'SURF', 'OBSV', 'PANA', '4519', 'LUXAU', 'NGH20', 'CAPAU', 'PPD', 'CETUW', 'CURNCY', 'PRSC', '2160455D', 'C5', 'AAM/U', 'OSTRW', 'ASTR', 'SX5E', 'MEOAU', 'LCINQ', 'SGTX', 'IMGN', 'FREQ', 'TWOU', 'STMMI', 'NBA/U', 'LONN', 'INKAU', 'FAZE', 'MAACW', '3222', 'LN', 'LABP', 'ASLN', 'VECT', 'YPSN', 'CCVI/U', 'PAFOR', 'CVET', 'PMGMW', 'PSTH/WS', 'ATVI', 'PNACW', 'FZT/WS', 'APE', 'SMZ22', 'GXH22', 'CZOO', 'CMLFU', 'TYH2', 'LMACA', 'HZON/WS', 'KURIU', 'IPOF', 'NRE', 'DBDRU', 'GGPI', 'ARNA', 'AABA', 'KL', 'MSP', 'PRPB', 'NIHD', 'LTYA', 'FOCS', 'OPA/U', 'ADGI', 'CIT', 'CTIC', 'CETUR', 'NQZ0', '1576747D', 'BCTX1', 'GEZ0', 'EBIX', 'AKUS', 'KDMN', '1SXP', 'BBLN/WS', 'PAH3', 'MONDW', 'NOVOB', 'MYOK', 'LIONW', 'COMDTY', 'PNT', 'PIPP', 'CD', 'MEOA', 'ARAV', 'PL/WS', 'CPE', 'AYX', 'WPCB', 'ADOC', '9991006D', 'DEH', 'CLM0', 'HCIC', 'WPCA', 'CNHUSD', 'FTCHF', '0211846D', 'SDACW', 'SMMC', 'SPLK', 'PTRAW', 'BBBYQ', 'CRHM', 'NGA', 'NGU22', 'DSKE', 'PBFX', 'OTRA', 'RVRA', 'BLU', 'FLIR', 'REVRQ', 'FLACW', 'EP0306126', 'EPAY', 'CHNG', 'YAC', 'RAVN', 'KURIW', '1279426D', 'SIRE', 'GFX', '4568', '-', 'CLM2', 'KRA', 'SBEA', 'OSTR', 'ALBO', 'SIX', 'FUSN', 'TWNT/U', 'FWPAY', 'SPK', '1916672D', 'MYOV', 'CLK2', 'THRX', 'XLNX', 'MXIM', '2746505Z', 'NVLN', 'WPCB/U', 'CLH2', '1573601D', 'P7.5', 'KRTX', '0', 'VSPRU', 'CVT', 'MUDS', 'CLX3', 'GRPH', '6EN9', 'RBT', 'PAQC', 'CERE', '0987458D', 'OEU1', 'CLZ1', 'WBAI', 'SRRA', 'MYL', 'MONCU', 'ACAXR', '09/28/27', 'SCRM', 'LGVW/U', 'RTYZ0', 'ESALY', 'TTM', 'MOR', 'EFHT', 'ASTRW', '2177859D', 'ZNGA', 'SCVX', 'CEREW', 'NVSAU', 'FZT', 'MITGW', '01/19/24', 'LHC/U', 'NBLY', 'LNDC', 'LVOX', 'MGI', 'CATM', 'CNST', 'TCDAQ', 'U-U', 'JOFF', 'JOFFU', 'SELB', 'SRNG', 'IFIN/U', 'FSRN', 'TWTR', 'ROVR', 'MAAC', 'NRCG', 'IP ...
# ['CNCE', 'SEC', 'OCAXW', 'ZVSAW', 'CNY', 'SIOX', 'PDCE', 'ROIVW', 'IM', 'NNAGW', 'IAM', 'LTCHW', 'CBRGF', 'RWE', 'VOW', 'KIII', 'TCBPW', 'FFH', 'MKDWW', 'MIMWQ', 'OAKUW', 'SS', 'XW', 'DECAW', 'EFTRW', 'WED', 'GNOG', 'EFHTU', 'THCA', 'ONFOW', 'AITRR', 'TMTCR', 'EXO', 'EMCGR', 'SEK', 'FDJ', 'CH', 'GWP', 'BMAQU', 'HZNP', 'ALM', 'AUROW', 'ASTLW', 'INFO', 'GLSTW', 'RTY', 'FTIIW', 'CAD', 'HTZWW', 'FIE', 'IPN', 'MZN', 'NNAGR', 'CLNNW', 'AMYT', 'SIVB', 'DHAIW', 'REGI', 'PTWOW', 'BOL', 'FIGXX', 'HGEN', 'NWTNW', 'HCARU', 'CHF', 'ACACW', 'ERT', 'SPAK', 'IROHR', 'GGPIW', 'OTIC', 'LFACW', 'FOUN', 'ABLLW', 'KIIIW', 'OPALW', 'RMCOW', 'LAZY', 'MDNA', 'LEXXW', 'FORLW', 'DKK', 'BDSI', 'SVMHW', '2330', 'NUBIW', 'NOT', 'GIWWW', 'HHRSW', 'SMXWW', 'LMN', 'FRE', 'RUBY', 'GLSTR', 'ZURAW', 'IN', 'ETTX', 'MSPR', 'AVR', 'BRR', 'IPH', 'FLFVR', 'TNONW', 'BKHAR', 'KIIIU', 'AIMAW', 'APTX', 'WGSWW', 'PRSTW', 'US', 'UR', 'GSAQ', 'EUR', 'IMTXW', 'GXI', 'HOLOW', 'GY', 'JPY', 'ECDAW', 'GR', 'SDZ', 'CASLQ', 'FAZEW', 'ACAXW', 'EMCGW', 'FLFVW', 'GBP', 'IROHW', 'JVSAR', 'SABSW', 'AFAC', 'JOY', 'SSPI', 'ICUCW', 'ACER', 'QSIAW', 'ENW', 'SPX', 'FRG', 'RVX', 'CVIIW']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2023-01-01 -> 2023-12-31)')
# ['']: %ticker%Y%ticker%F%ticker%T%ticker%z%ticker%M%ticker%i%ticker%s%ticker%s%ticker%i%ticker%n%ticker%g%ticker%E%ticker%r%ticker%r%ticker%o%ticker%r%ticker%(%ticker%'%ticker%$%ticker%:%ticker% %ticker%p%ticker%o%ticker%s%ticker%s%ticker%i%ticker%b%ticker%l%ticker%y%ticker% %ticker%d%ticker%e%ticker%l%ticker%i%ticker%s%ticker%t%ticker%e%ticker%d%ticker%;%ticker% %ticker%n%ticker%o%ticker% %ticker%t%ticker%i%ticker%m%ticker%e%ticker%z%ticker%o%ticker%n%ticker%e%ticker% %ticker%f%ticker%o%ticker%u%ticker%n%ticker%d%ticker%'%ticker%)%ticker%
# ['GRAL', 'IROH', 'AITR', 'KYTX', 'ADGM', 'GLBL', 'BKHAU', 'GIGGU', 'DJTWW', 'JVSA', 'TEM', 'BKHA', 'CTNM', 'JVSAU', 'GIG', 'CALTX', 'HLXB', 'CGON', 'SW', 'ANRO', 'PCSC']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2023-01-01 -> 2023-12-31) (Yahoo error = "Data doesn\'t exist for startDate = 1672549200, endDate = 1703998800")')
# ['FP']: Y%ticker%ricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2023-01-01 -> 2023-12-31)')
# C:\Users\MukeshwaranBaskaran\AppData\Local\Temp\ipykernel_1692\857452612.py:27: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   returns_data = prices_data.pct_change().dropna()
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 33
#      30 df_combined = pd.merge(df_daily_ticker, df_daily_factors, on='Date', how='inner')
#      32 # Add returns to the combined dataframe
# ---> 33 df_combined = df_combined.merge(returns_data, left_on=['Date', 'Group'], right_index=True, how='left')
#      34 df_combined.rename(columns={group: 'Return' for group in groups}, inplace=True)
#      36 # Define a function to calculate betas for each group using regression
#
# File c:\Users\MukeshwaranBaskaran\Downloads\Project_KISKI\.venv\Lib\site-packages\pandas\core\frame.py:10832, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10813 @Substitution("")
#   10814 @Appender(_merge_doc, indents=2)
#   10815 def merge(
#    (...)
#   10828     validate: MergeValidate | None = None,
#   10829 ) -> DataFrame:
#   10830     from pandas.core.reshape.merge import merge
# > 10832     return merge(
#   10833         self,
#   10834         right,
#   10835         how=how,
#   10836         on=on,
#   10837         left_on=left_on,
#   10838         right_on=right_on,
#   10839         left_index=left_index,
#   10840         right_index=right_index,
#   10841         sort=sort,
#   10842         suffixes=suffixes,
#   10843         copy=copy,
#   10844         indicator=indicator,
#   10845         validate=validate,
#   10846     )
#
# File c:\Users\MukeshwaranBaskaran\Downloads\Project_KISKI\.venv\Lib\site-packages\pandas\core\reshape\merge.py:170, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     155     return _cross_merge(
#     156         left_df,
#     157         right_df,
#    (...)
#     167         copy=copy,
#     168     )
#     169 else:
# --> 170     op = _MergeOperation(
#     171         left_df,
#     172         right_df,
#     173         how=how,
#     174         on=on,
#     175         left_on=left_on,
#     176         right_on=right_on,
#     177         left_index=left_index,
#     178         right_index=right_index,
#     179         sort=sort,
#     180         suffixes=suffixes,
#     181         indicator=indicator,
#     182         validate=validate,
#     183     )
#     184     return op.get_result(copy=copy)
#
# File c:\Users\MukeshwaranBaskaran\Downloads\Project_KISKI\.venv\Lib\site-packages\pandas\core\reshape\merge.py:786, in _MergeOperation.__init__(self, left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, indicator, validate)
#     779     msg = (
#     780         "Not allowed to merge between different levels. "
#     781         f"({_left.columns.nlevels} levels on the left, "
#     782         f"{_right.columns.nlevels} on the right)"
#     783     )
#     784     raise MergeError(msg)
# --> 786 self.left_on, self.right_on = self._validate_left_right_on(left_on, right_on)
#     788 (
#     789     self.left_join_keys,
#     790     self.right_join_keys,
#    (...)
#     793     right_drop,
#     794 ) = self._get_merge_keys()
#     796 if left_drop:
#
# File c:\Users\MukeshwaranBaskaran\Downloads\Project_KISKI\.venv\Lib\site-packages\pandas\core\reshape\merge.py:1607, in _MergeOperation._validate_left_right_on(self, left_on, right_on)
#    1605     if self.right_index:
#    1606         if len(left_on) != self.right.index.nlevels:
# -> 1607             raise ValueError(
#    1608                 "len(left_on) must equal the number "
#    1609                 'of levels in the index of "right"'
#    1610             )
#    1611         right_on = [None] * n
#    1612 elif right_on is not None:
#
# ValueError: len(left_on) must equal the number of levels in the index of "right"

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm

# Step 1: Load and preprocess portfolio data
df_daily_ticker = pd.read_excel(r"C:\Users\MukeshwaranBaskaran\Downloads\Project_KISKI\Data\KISKI_Data_PositionLevel_Daily_Ticker_Net.xlsx")
df_daily_ticker.columns = df_daily_ticker.columns.str.strip()
df_daily_ticker.rename(columns={"Trade Dt": "Date"}, inplace=True)

# Ensure 'Date' is in datetime format
df_daily_ticker['Date'] = pd.to_datetime(df_daily_ticker['Date'])

# Step 2: Forward fill missing dates
df_daily_ticker.sort_values('Date', inplace=True)
df_daily_ticker['Date'] = df_daily_ticker['Date'].ffill()

# Step 3: Load and preprocess factor data
df_daily_factors = pd.read_csv(r"C:\Users\MukeshwaranBaskaran\Downloads\Project_KISKI\Data\F-F_Research_Data_5_Factors_2x3_daily.CSV")
df_daily_factors['Date'] = pd.to_datetime(df_daily_factors['Date'], format='%Y%m%d')

# Step 4: Merge portfolio and factor data
df_merged = pd.merge(df_daily_ticker, df_daily_factors, on='Date')

# Check for missing values
print("Missing values in merged data:\n", df_merged.isnull().sum())

# Step 5: Calculate daily portfolio return
df_merged['Portfolio_Return'] = df_merged['Net (%)'] / 100  # Assuming Net (%) represents the portfolio return

# Ensure that all necessary columns are numeric
numeric_columns = ['Mkt-RF', 'SMB', 'HML', 'RMW', 'CMA', 'RF', 'Portfolio_Return']
df_merged[numeric_columns] = df_merged[numeric_columns].apply(pd.to_numeric, errors='coerce')

# Check for missing values again after conversion
print("Missing values after conversion:\n", df_merged[numeric_columns].isnull().sum())

# Drop rows with any missing values in numeric columns
df_merged.dropna(subset=numeric_columns, inplace=True)

# Step 6: Prepare data for multi-factor regression
X = df_merged[['Mkt-RF', 'SMB', 'HML', 'RMW', 'CMA']]
Y = df_merged['Portfolio_Return'] - (df_merged['RF'] / 100)  # Excess portfolio return

# Add constant to model
X = sm.add_constant(X)

# Fit the regression model
model = sm.OLS(Y, X).fit()

# Get factor betas
betas = model.params[1:]  # Exclude constant

# Step 7: Calculate active premium
annualized_portfolio_return = (1 + df_merged['Portfolio_Return']).prod() ** (252 / len(df_merged)) - 1
annualized_benchmark_return = (1 + (df_merged['RF'] / 100)).prod() ** (252 / len(df_merged)) - 1
active_premium = annualized_portfolio_return - annualized_benchmark_return

# Step 8: Calculate tracking error
tracking_error = np.std(df_merged['Portfolio_Return'] - (df_merged['RF'] / 100))

# Step 9: Calculate upside/downside capture ratios
upside_capture = (df_merged[df_merged['RF'] > 0]['Portfolio_Return'].mean() /
                  df_merged[df_merged['RF'] > 0]['RF'].mean()) if not df_merged[df_merged['RF'] > 0].empty else np.nan
downside_capture = (df_merged[df_merged['RF'] < 0]['Portfolio_Return'].mean() /
                    df_merged[df_merged['RF'] < 0]['RF'].mean()) if not df_merged[df_merged['RF'] < 0].empty else np.nan

# Step 10: Calculate information ratio
information_ratio = active_premium / tracking_error if tracking_error != 0 else np.nan

# Step 11: Calculate correlation with benchmark
correlation = df_merged['Portfolio_Return'].corr(df_merged['RF'] / 100)

# Step 12: Calculate maximum drawdown
cumulative_returns = (1 + df_merged['Portfolio_Return']).cumprod()
peak = cumulative_returns.cummax()
drawdown = (cumulative_returns - peak) / peak
max_drawdown = drawdown.min()

# Output results
print("Factor Betas:\n", betas)
print("Active Premium:", active_premium)
print("Tracking Error:", tracking_error)
print("Upside Capture Ratio:", upside_capture)
print("Downside Capture Ratio:", downside_capture)
print("Information Ratio:", information_ratio)
print("Correlation with Benchmark:", correlation)
print("Maximum Drawdown:", max_drawdown)
# Out:
# [**********************64%******                 ]  1615 of 2505 completedFailed to get ticker 'FST/WS' reason: Expecting value: line 1 column 1 (char 0)
# [**********************65%******                 ]  1637 of 2505 completedFailed to get ticker 'HZON/WS' reason: Expecting value: line 1 column 1 (char 0)
# [**********************66%*******                ]  1641 of 2505 completed
